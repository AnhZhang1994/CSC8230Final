# %%
import sqlite3
import pandas as pd
import os

# Connect to the database
db_path = 'opensubs.db'
if not os.path.exists(db_path):
    print(f"Error: Database file '{db_path}' not found.")
else:
    conn = sqlite3.connect(db_path)
    
    # Get database tables
    tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
    tables = pd.read_sql_query(tables_query, conn)
    
    print(f"Database size: {os.path.getsize(db_path) / (1024**3):.2f} GB")
    print(f"\nTables in database:")
    print(tables)
    
    # For each table, show schema and sample data
    for table_name in tables['name']:
        print(f"\n\nTable: {table_name}")
        
        # Show table schema
        schema_query = f"PRAGMA table_info({table_name});"
        schema = pd.read_sql_query(schema_query, conn)
        print("\nSchema:")
        print(schema)
        
        # Show sample data (first 5 rows)
        sample_query = f"SELECT * FROM {table_name} LIMIT 5;"
        try:
            sample = pd.read_sql_query(sample_query, conn)
            print("\nSample data:")
            print(sample)
        except Exception as e:
            print(f"Error fetching sample: {e}")
    
    conn.close()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Database size: 127.42 GB
#
# Tables in database:
#    name
# 0  subz
#
#
# Table: subz
#
# Schema:
#    cid  name     type  notnull dflt_value  pk
# 0    0   num  INTEGER        0       None   1
# 1    1  name     TEXT        0       None   0
# 2    2  file     BLOB        0       None   0
#
# Sample data:
#    num                                               name  \
# 0    1  attachment; filename="alien.3.(1992).eng.2cd.(...
# 1    2  attachment; filename="identity.(2003).slv.1cd....
# 2    3  attachment; filename="ghost.in.the.shell.2.inn...
# 3    4  attachment; filename="planet.of.the.apes.(2001...
# 4    5  attachment; filename="the.city.of.lost.childre...
#
#                                                 file
# 0  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x9a\x0e\x...
# 1  b'PK\x03\x04\x14\x00\x00\x00\x08\x00m\x10\xf1T...
# 2  b'PK\x03\x04\x14\x00\x00\x00\x08\x00w\x10\xf1T...
# 3  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x84\x10\x...
# 4  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x8e\x10\x...

# %%
import sqlite3

conn = sqlite3.connect("opensubs.db")
cursor = conn.cursor()

# List all tables in the database
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables in database:", tables)

# Inspect columns for a specific table (e.g., subtitles)
cursor.execute("PRAGMA table_info(subtitles);")
columns = cursor.fetchall()
print("Subtitle table columns:", columns)

conn.close()
# Out:
# Tables in database: [('subz',)]
# Subtitle table columns: []

# %%
# Sample from subtitles table
conn = sqlite3.connect("opensubs.db")
cursor = conn.cursor()

cursor.execute("SELECT * FROM subz LIMIT 10;")
sample_rows = cursor.fetchall()

for row in sample_rows:
    print(row)

conn.close()
# Out:
# (1, 'attachment; filename="alien.3.(1992).eng.2cd.(1).zip"', b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x9a\x0e\xf1T\x08zK{OH\x00\x00\xb6\xa0\x00\x00\x13\x00\x00\x00Alien.3.ENG.CD1.sub\x8d\xbdK\x93\xe3\xc6\x92%\xbc\x1f\xb3\xf9\x0fPmj\xc3J#\x89\xf7\xaa\xac\xf4\xaen\xbdZU\xd62};\x90\x04\x93P\x92\x04\x1b\x00\x8b\xca+\xf0\xbf\xcf9\xc7=@fI\xf7\x9b\x19\xeb\xb9(%#\x02\x81\x08\x0f\x7f\x1e\xf7\xf8kY&\xc9\xf5\xafx\x9e\xc7\xd7\x0fC\xd57}\xd4\x1c\x87\xba\xeb\xce\xa7\xa1\xde<\x8c\xdf6]\x8d\xbfD\xeb\xee\xb9}\xac\x8f\xcd:Z\xb7\x87S\xd5\r\x87\xfa8<\xfc\xef\xff\xc5\x9e\x19\xfa/\x8a\xf8\xfak}\xaa\xab\xe1\xff\xa5\xcf\xa2`\x9fe\x9a^\xdf\xed\xf7\xd1\xa9\xee\xfa\xf6x\xac\xf7QW\x9f\xdan\x88\x86\xf6\xe1A\xed\x96i\x81vq\\^\xebC\xdda\xac\xf5sT\xf7\xeb\xeaTG\x9f\xea]\xb3\xde\xd7\xd1\xbe:\x1f\xd7\xbbS\xb5Q\x878Y\xa2C\x82\x0e_\xd7\xf5)\xeaO\xd5\xba\x8e\xb6\xfb\xe6q7D\x97\x06\xef\xc2L0\x8bu\xed/H\xd4>\xc5\x12`\xbe\xaf>\xbe\x8a\x0e\xcd\xf1\xdcG\xcby\xd4\xd7\xeb\xf6\xb8\xe9\xd9\xaa\\.\xe3+\xfe\xb7,\xae\xef\x8e\xd17\x0f\xdf<\xfc\xf7\xc3\xeb\x9eC\xd5\xd1\xa6\xbd\x1c\xd5&\x9e/\xd0&N\xe7\xd7\xef\xeaA\x7f\xc6gD\xc3\xae\x8eVu\xb5\xde=\x8c\x1fw5\x96\xe5P=\xe3\x0fQ\x8b\x1f:\x1b<N9x2\xcf\xaf?\xb5\x97/\xf8\x97<\xe1_\n\x0c\xf8\xb1\xda?q\x98C\xcd\xa6\x8b8\xcb\xe7W<\xf2\xa4\xd0\xc2u\xfc\xaeYT\x85\x7f>\x8c?\xd4\x03f\xf6\x88\x194C\xf4\xd86\xc7G\xeb\x98\xa7\x0bv,\xe2\xe4\xfa\x9f\\\x98\x86\x8b\x8cf\x98\xc5\xc3\xf8\x15?\xa4=>D\xbfj\x10u(\xe2\x9c\x1d\xca\xf9\xf2j\x7f\x8d\xbe\xe7\xf4/5F\x9dE?v\x0f\xd1\xd7X\xceV\xdf\xbeH\xe6Y\x8a\xd6\xc9\x02\x9f\xf2]\xf3\xa9\x8e\xb0\x84\xfd\xd0\xd5\xc7\xc7a7\x1b\x7f\x8e~h\xbb\xcd\x8c\xdfQ\x1f7\xe7\xce\xbe\x05\x8d3\xf6Yf\xf9\xf5\xb7\x1a;\xbfn\x1f\x8f\xcd\xbfj,Y5\xf0=\x15^wj\xdb.\xea\x1b\xd0F\xd7\x8f\xd8!.\xe7\xae\xc2\xb6D\xed6\xaa\x8e\xf8\xbf\xc7\xee9\xfa\xae\xdd\xd8\x90\xcb\x92\xcb\x93`\xff\xafX\x08\xb5^7\x1d\xa9\x04K~>\xae\xba\xf6\xa9>\xda\xce\xb3\x95\xde\x9f\xcc\xd3\xeb\xf984{5\xdfT\xcf\xf6k\xbaX\xf2\xd7\x14\xc7\xe2M\xf4\x0e$\xf30\xfaS?ge\xc9\x9f\xf3\xbc\xbc~\xc4\x84\x9e\xa2\xe7\xf6<\xc3\xba\x1f\x87}\xad\xc6\x1fw<I}\xd4\x9d\x0f\xf8\x04\x90\xd2\xd0\xb5{\xeb\x9b\x17\x1a\xbaX\xe4W\xad)?\x94\xef\xdeV\xeb\xa1\xb7&\xc5R\x1fRd\x8b\xeb;,\xa5\xf6g\xcbwDO\xc7\xf6\x12\xbe\xa0\x9c\xeb\x0b\xca"\xbfVQ\x1c\xe7\xd1\xa1\xdd\xe0\x10\x19\x81\x866Z\x92\x94\x1b\xb4\xee\xaa~\xf7f\x8f\xe5\xab7\x91\x88\x11\x0b=\xcf\xe6so\x8bF\x05\xdb.\xe2\xf9\xb5\xb5\xb5\xc6\xdc\x8f\xa0\xa1\xe8R\r a5Z\xc4\xb1\x1a\x95\xcb\xabQ\xf4\xa5\xc2n\x1c\xeb\xa8?w\x9f\x9aOm\x17F[\x94\xa4\x89t\x89\x95\x1a.m\xb4\xa9\xab\r\xf6\x0b\xff?\xdatm\xb3\xf1}\xae\xfaq\xd7\x9e\xea}\xdd\xf7\xfb\xe7\xa8?`\x8a\x98\xdd\xaa~\xc6\xe1#;\xa8\x9a\xce\x86\x8b\xe7\\\xb5\x14\xb4\xcf\xf7No\xe3\x1aW\xd1\xa5=T\xb63i\xb2L\xd8.]d\xd7\xf7\xd1\x1f\xe7\x9e\xef8\x92\xda\xa3\x1eGO/}\x0f\x1a\x02\x91\x0e\x15\xa8a\xac\xa2O\xed\x85\xab\xbb\xae\xf7\xcd\xaaZ\xdb\xfe\xa3\x7f\xa9a\xf2%\xf6\xffCk=H\x95\xfb=)\xe1#\xc7\xa9\xf6}\x0b>\xb7\xde\x9f7u\xcf98u\xa0\x97>=[\xa6\xe8\xfc{\xdd\xb3\xc7o\xf5\xebO\xean\xef\xd5\xf2~\xb2\x03\xcf\x96Z\xf9\xac\\\xf0m\xbb\xf3\xc0\xbd\xeep\xd4V8km\xd7\xd7\x1c\xe1\xfd\xebM\xb4o\x9ej\xff\x96Y\xf8\x98-V\x01\x1b\x10\xd6=+\xb5\x00y\xba\xbcn\xda\xe8\xd8b\x9e\xa7\x13\x8eWS\r\xb51\xe2\xe33\x0e\xd6\xbeY?\x8f\x98N{\xe1\x06c\'9\xec\xb6\xab\xeb\xfds\x18)O\xf5\x19\x05\xc8L2\x01\xbc\xf1\x11g\xe9\xd2\x0c;|\xf6\x01\xe3\xf5#w\x94\x9f\xd2\xd5Xi\xac"\xff\xdd\x0f\xd5vkC\x14s-c\tz\xfe\x8d\xb3\xc5\x11$\xcf\x01C\xab\x8e}\xd8\x14l!V\xf6SS_Fv\xc7d{\xb2h;\xe3\xcfQ{\x1e\xfafSO\x84U\x92\x1b/\xb2y\xbc\xbc\xd6\xfd\x89\x1f\xb6\x07\xe98\x11\xcc\xc6\x8a\x04\xf1\xa9i\xf7\xd5\xd0\x80\x8c}N\xbb\xaa;\xb4\xc7\xf0i\xe8\x9cj\x8cb\x8e\xa3sj\x07\x1c\\\x0c\x83\xe9\xd5\xd5S`4\xfd\xa9\xe9\x9a\xe1\x8c?\x9f\x8f\xcd\xf0\xec\x1d\x0b\xbd\x1c\x9c\x81\\\xab\x12K\xc4\x9eV\x17\xfcs\xb43\xdaE[\xac"\xd6\x8a\xa2\x14#\xe1\xf3\xb0VX?\x1b\x01\xc7\x9a#,\xd3\xf2\xfa;\x0e\xb4\xa4\x12\xd8\xd3i_W=H\x1fk\xc23>\xdeSjW\xff\xcf\x19\xeb[\xf3\xf0`q\xd6g\xd0@]\x1dl\xbce\xc6\x83\x91\xc5\xa0\xfb\xefq\x92\xb6g\xac\x06i\xa3~\x9e\xc6\xe69\xc5Wq\x15\xb5\xa8\x98s\xfd\x14\x96"^\x92\xd3g\tV\x95\x9 ...
# (2, 'attachment; filename="identity.(2003).slv.1cd.(2).zip"', b'PK\x03\x04\x14\x00\x00\x00\x08\x00m\x10\xf1T\xe7>\x82\x17XO\x00\x00\xd9\xad\x00\x00\x18\x00\x00\x00Identity.DVDRiP.XViD.sub\x8d}\xdbn\xe4F\xb6\xe5\xfb\x00\xf3\x0f\x94q\x80yQ\n\xc9;y\x80A\xa1}\xca\xe3\xb6\xcb\xa5*X\xd5:3\xf5\xc6T\xd2\x12\xf3B&\xf2\xd6p\x9a\xf9\x03\xfd\xd0\x1f\xa0\x07}\x8f?E\x9f1k\xad\x1d\xc1L\xa9\xca\xee>8\xed(%#\x82\xc1\xb8\xec\xeb\xda;~K\xa3\xe3oaT\x1c\x7f\xfb\xf5?\x9b\xe3\xa7\xdd\xb4\t\xa6U[o\x82\xfb*h\x9b`\xd2,\xba`[-\xaf\xfe\xe7\xff\xf8-,\xca\xe3oQ^Z\xd5\x7f\xd6\x8bfy\x19<\xb1\x086\xcde\xaf_\xa7\x15\x9a\x04\xcd\xe1\xbei\x9b\x05\x1b\xc5c\xf4\x1f\xa7\xa95\x1a\xbd\x9b\xd5\xc1f\x8b\xff\xd5\xc1\xb6\x0b\xdaj\xf7\xdc,\x9a7\xacW$\xc7\xdf\x92\xd8u~V\xcd\xd5\xb1\xee\xf1\xd3\xaa\xde,\x9b\xbb\x9am\x92$>\xfe\x96\x8eC\xd7\xf7\x0f\x87e\xb3Y4\x0b\xb4\xe2\x88\x82Y\xc7\x01\xa4c\xbc;-r\xab\xf4e\x1d7\xf0y\xa7\x9f\xf0\xbd\xc1c\x1dt\xdbu7G\xe3,\xc7\xe8\xf3t\xecG_\xcd8$T\xd8\xac\xbae\xdb`8\xcd\xc1\x8d\xac\xd9l\x9b\x87\xe0\xb9\xdat{\x8e\xad\xc81\xb62\xcd\xac\xe5u\x1d\x1c\xaa\xe9\xfai7\xb3\x8f\xda\x07\x93E\xf3\x849\n\xee\xd7\xcbn?\xab.\x83i7\xdfv\xeb\xab\xfe\xdf\xab\xcf/+3\x8c+\x1c\x17\xe1\xbf\xf9\x8e\x7f\xb7o?\x96\x0b\xaey8.\xb9?B\xbf\x80\x1f\xbb}\xcd\x86\xcb\xe62\x98\xdbt\xf8\xb9\xb0\xee1\x8f\xfbn\xd6\x04\xcbj\xd9h\xd7DI\xa1\x1d\x16\xbb\x1enT}\xc9\x96\xcb\x0e\xeb\x8c\x8a\xb5*\xc6!_\x15g\x89U\xfc\xc3zI\x88\xc5\x0c\x93,}]\xef\xb4\x07Q\x1d+Y\xb1a\xc5\x86U0\xdf\xad\'\x9a\xb50\x1fc$a\x9e\'\xc3\xa2b\xed\xa7\xdd\xe2\xbe\x0b\xf6\xd5\x06M\xad\x17\xcdQ\xbd\xaf\xd0\x0b\xf6\xff\x1b\xed\xff\x08m\xc2r\xec\xb7\xc3\xdbn\xbe\xa8\xd7\xc3\xcb\x0e\xd5\xaa\xdb,\xeaV\xaf\x89\xa2\x18\x95\xa38\xf4\xbb\xf3/\x8b&\xd8\xd7\xd8\xd4\x97\xa8h3g/\xda\xd4S\xfc\xb5\xea\xee\xbb}\xb5\x9eU\x98\xdb\x03\x86\xdcv|%\xda\xa7\xec\xc5\xef\xa3\xd1\x8f\x95\xff\xc8n\xb2\xe6\x01\x9a\xf1\xbc\x1d\xda\n\xbd\x1f\xa6\xebj\xdfl\x9b\xab+\r \xe6\x9e\x8f\x12?\x00\xfcz\xbf\xa8\xf6\xdd\xa4[h\x1a\xa3\x84\x9dFi\xe4\xa6\xf1#\xf6|=\xd9\xcdp\x08\xda\x9a\xe3\xdb\xd7\xcf\x97\xf8g\xb0\xa8\x83j\xb3j\xd6M\xebw\xd0\xad}\x06+\xe94iv\xd0\x13\xc9C\x16\xf9\xa1\xde\x9c\x9d\x92\xdd\xb2[\xdb\xb9\x88\xb2|L*\x12\x8d\xbf\xd8\x0en\xdcy\xccq\x17~\\\xf8\xd5\x16\xf4\xbf\xba\xc5n9i\xaa\x80\x9f\xd1v\xc1\x12\xa3\xe8l@?\xee\x9e0\xd0\xff\xaa\xd6\xdd\xa2i\xed\xeb\n\xd2\x93\xa8\x8c\xe2/6\t\xe8\xdbhD\x8a\x13rK\xc6\xd1p\xba\xb9B$:\xfbF\xe3\x1d\x88\xce#^\x84\x07X\x12\xec\x86\xbbzo\xe3DC\xbc!\x8e\xe3b\x18\xe7>\xf8\xa9\x9a\xd7\x7f\xef\xd6\xdb\x87\x9d[\xa6p|\x85\xc5\xc4&\\\xd4\xdb*\x08\xcb\xb2\x10\xb1KRQ\xc5\xb1?U\xd7\xdcd$\xbcA\x83\xddjM\xd7\xddl\xb3mE\x8e\xf5\xbe\x8c\xf3\x12g\xc50\xbf\xc1\xbc\xe3\x07q\xf7`\xef`\xc0Z\x878OP#.B\xf7Y\xda\xde\xdc\'\xdc\xdc\xf3E\xf3\\/\x1d\xbd\xc5\xc6\x88\xcb\xb0\xf4\xc7\x00\x8f\xb8TK\xad\xec\xbc[\x8b\xb4o5\x9b8q\x18o2P\x81\xef\xab\xf5\xaf"\xc0\x11\x9b\'Q6~\xfd{.j\xeeg\x9f\xbf_jn\'\xbbi+z\x8f\x87\x18f\xc2\xed\x89=\x1d|\xbf\xae\xef/I\x8a@F\xf7\xbb^\xa4x7\xad\xf5\xe5\xa8\x94\xb2j\xeaf\xfa\xc3j\xdd\x81\xd8j\x0b\xe2\xf8\x9d\xbe\x0b\xa7\x18\x04\xcc\x96\'I2\x0e9M\xc6Z\x99\xba\x9dV\xeb`\xd2\x05\xdd\x04Gm\xd1v\xcf8/\x15\xf6\xeec\xd5\xe2\xc4\xdf/\xea)X\x0b\xa6\xb0^W\xc1\xcf\xcd\xbe^o\xd4K\x9a\xf0C2,\xf2\x87\xc9\xbaZN\xb4\x13\xdb\xea\x91\xc7}_\x1f\xea9\xc6\xd0\x90f\xe0\xc4\xce\xe6\xd5\x02\xd37%\xf9\xac\x0e\xa0\x8f\xd3\xb6\xde\xb7\xcd\\\x1de\t\x87\x93\x87\xd1\xf1\xe3\xba\xd9vO\r7\x1byN\x002\x83\xfd\x0c\x06\x8am\x8e_&z\xb2\xc2|`LU+\x1a\x9a\xe4q\xcc\xd6\x98\xd5\xd1\x87\x80_\xba\xaa\xdc\x9ao\x8d\x13\xe6d\xcbI\x81)\x02\x89\xc0\xe9\xc0\x8e\xc5\xd6\xe9&\xfb\xfa\xf1\x99\x14\xa9\xbf\xdd\x88\xd8c\xf4\x87\xfbnJ\xae\xbe\xea\xc0\xb0:q\xf6\xa4\xd0d\x958\x94\x9fA\xc4\xd6\x184kb\x10\xd3 \x0cv\xeb\xae\x9f\xafk0tp\xbb\xe0\xbb\xc5\xaf"p\xa8M\xc6:\xf6\xec\x17\rwX\x95\x05\x1b\xa2\xce\x9b@\x1b\x0fL^$\x02\xc3\xec\xfdv|\xac[v\xbd\xef\x0eo\xc4\x9f\xc7\t\xfb\x01\xbf\x1c\xbd\xb5\t\x0bf8\xa9\xe8f\xca\xf9\xec\x9e\xf856;b\xbdu;_W\xdb\x00\xcb\xd16\x9e\xc5\xe7\xd8Ki\x98\x96G[:\xb4ZS\x10\xd96\\\xd3M\xb7\xad[R]\x0cf\xe3(\x06\xa4\x9b\xe6\xb0_\xd4\xd88A\xd3r\xbeA:\xf1\xef\xb6 ...
# (3, 'attachment; filename="ghost.in.the.shell.2.innocence.(2004).eng.1cd.(3).zip"', b'PK\x03\x04\x14\x00\x00\x00\x08\x00w\x10\xf1T&\x99\x00VO_\x00\x00J\xf6\x00\x00\x1e\x00\x00\x00Innocence.2004.DVDRip.XviD.srt\xad\xbd[\xb3\xe3\xc6\x91.\xfa\xae\x08\xfd\x07Z/~a\xeb\x00\xa8*\\\x1c;\xc6\xd1\x96d\xab\xc7\xba\x8dZ3\xda\xf3\x88Eb-\xc2M\x12\x1c\x90\xec\xe5\xa5_\x7f\xf2\xcb\xccJ$\x96$\xc7>qv\x84\xa2[\r\xa2\x12@UVV^\xbf,?\xfd\xa4(\xfeD\xff\x95\xc5\xb6I\xc5\xe6\xcd\x9b\x7f\xdb\xe8\x85\xb8M\xa1\xfd\xf4\x93\xff5\xfe\xdb\xbb\xc7\xcdt\x9f7O\xd3\xfe\xba\xe9\xcf{\xfe\xc7a\xba\x0c\xf4\xafy\xf8\xf4\x93\xf3t;\x8c\xe7\xa7\xcd\xc3\xfd\xb6\xb9\xee\xc6\xe1|\x1b\x1f\xc7\xdd\xe6r\x18\xce\xd3i8_\xb7\xff\xeb\xff\x19\xff\xed\xd3O>\xfd\xa4\xb2\x87\x81v\xe7\x1f\xd6mSQ\xf0\xc3n4l3\xde6\xa7\xfb\xf5\xb6y\x186\xd7~\xdcon\x87\xfe\xc6\x8f=N\x1f\xe9\x89\xe3\xd5?\xa8\xbfn\x9e\x87\xe3q\xf3f\xf3\xd97\x7f\xfc\xea\xe3\xb0\xf9\xeb\xfdv\x9f\x87\xcf\xf2c\x83<\xb6\xfcS\x91\xb6m\x9d\xec\xb1t\xa1\xdd\x96U\xf7\xe9\'\xdf?\\\x87\xf9\xe30o\xaa\xa2\xc2\x88h#\xdam\x15\xa2\x1f\xd1m\xdb.}\xfa\xc9\xdby\x1e?\xf6\xc7\xcdt\xa6w\x1b6\xfdn7\xee\xe9}6\xd7\xf16\x80B\xca\x14h^\x8b"8\neE$\xe9\x95\xbe\x9b\x9e7\xd7[?\xdf\x98\xc0q\xa4\xf7~\x98\xa7~\xbf\xeb\xaf7\x9aM\x10\xa93\x91D/^\xfa\x17O\rQ\xa5\x17\x7f\xa6y\xf9\xe3\x95)\xd0\x93\xef\xfdm\x9c\xce\x7f\xc6\xd0\xc6\x866\xdb\xaellhE\xb3\xbd\x8d\x91\xbe\xf2/\xc3\xe34\x0f\x9bTmN\xe3\xf9~\x1b\xae\xdbO?yw\x96\x99\xee/\xf4^\'|\x0f\xcd\xed\xe38_\xe5\xc3\xb6\xa0\xdc\ne&\x94R\xf0\x94\xabm\xdb\xd2\x87\xffDo\xf3q\xdc\xdd\xc6\xd3\xe6\x99\xc6\x9f\xee\xf3~\x98\x87=\x8d\xfe\xfbx<\xd2,\xcf\xfdy\xd3?\xf7/ \xd7\x19\xb9j\xdb\xb5\x9d\'\xd7l\x9b\x8ex\x02\x1c7\xca4_\x87\xddD\xff\xd2w\xa96\x97\xe98\xee\x86\xcd\xf4Hl0\xccW\xe2\xd0\xdb\xe6\x03\x9e\xb1\x07\xe9\xb20\xda\r\xadZt\xb4i\x11\x8aD_\xd2\x13\xdb\xd0g\xd2\x0b\x11\x99\x87\xe3\xb4\xfb\xc0\xefy\x1d\x87\xa7a\xf3L\x94\x98\x03\xb1J\xc3~\xd3?\xde\xc0"y\xbe\xf8\x11e~DY\x13K\xd7\xfe\x11\xed\xb6\r\xc4H_\xf6\xa73\r~$\x0e\x9d\x9e\xaf\xf4\xae\x9b\xeev\xd8\xbc\x1fvX+\xa6Q\x19\x8dv\xdb\x85\xd6\xd1\xa8\xc26\xc4\x92gt^\xde\xe7\x84u#6\xb9\xf7\xc7\xdb\x0b\xa6\xe6z\xdf\x1d6\xfd\xc2\x01L5d\xaaD$F\xbfN\x15\xb1D \x06\xf9i8\xd2|\x9ex\xd6\xc63}\xf6\x97\x13m\xa4\xcdy\x180\xe1\xc4\x1d\'\xa6F\xe4/\x97i\xbe1_\x95\xd1\xc8\xb6\xdb"z\xc6\n`,"\xfbW\xe6\x97\x1fxi\xb6\x1b~sz\n\t\x8b\xfc\xbc\xfe\x89\xa6\\\xa6/ej\x01\xccTxj\xd56\x95\xb4B?\x0f&\th\x83\xbe\xd0w\xcf\xc3\xe3\xfd\xc8\xa3u\x7f\xc4?\x15\xf5\xb6\x8d\xcb\xe4G\xec\xdb:\xd2\x0c|=\x1c/\x9b\x13\xef\xc8\xb2\xb1\xbb\xbbmt\xbb)\xfe\xa9,\xb7\x15V\xc1\xdf\xadl\xde\xfe\xa9l\xb6U\xb7\xd0ny\x95\x12\x11{\xfb0\x91\xc0\xfbqz\xa0\xe9\xfb\x96y\x9c\x07v6\xb0\xdb\x16N\xda\xb4\x7f\xaa\xcam\xacS^\xcd\x03m\x8d\x87\x81d]\xab;\xe4\xba\xd9\xdfg\xc8Q\x92\xa6\x90h\xc3\x07\x96\x99E\xa6G\xc3S\xddxz\x89$\t\xfd\xfc\x96\xd8B\xf6\xdb\x95\xa8\x92\x1c\x99\x87\xeb\xc0be\xa4\xbd\x86\xf7\xe3\xc9\xaeJ\xa3Toc\xe1\xdf,\x94\xf4\xaa\x9dP"\x06\xa5\x91\'\x88\xf6\xcd\xb7\xd3~ \x99H\x0b\xf38\xd3\xc2\xfd8\xfds\xf3\xc54\x133\x18\x9bUU&J4R\x8c\x9eh\xd86\x05\x7f.}\xce\t\x94\xe8\xef~C;\xe7\x86\xa5\xbc\x82\xb5\xfe\x81\xa5%N\xa3MH\xd2t\xe1\xde*\x18\xd9@\xa2/x\xb2$\xfab\x14)\xb3\xa3\xe1\xc4Z4u;\x12)O\xf4\xd1\xd3y`z\x8f\xf3@\xeb(;\x96>\xe7\x856\xc7\x13\xb6aO\xbc\x88\xfd\xbe\xbb\xd1v\xa2}H\x9f\xc4\xcf\x8b\xf6\xbcf[\xc6\xce?\x0f\xdc\xa2\xf2\x1a\xe2\x02r\xe8\xd4\xef\xe8\xc4\x1b\xb0J3\xa6{\xd7g\x99S%#\xd4m\x9b\xd6Or\xac\xb6u\xa2\xe9z\xbb\xdbM\xf3\x9e\x17zbj$\xbe \x1f\x89\x0e\xb6\x19S\xa93\x15\x1a\xd4\xa4\x15\x15bu0\xbe0\x11\xcdh>}\x9f\xe7\t\x7f\x8e\xf8\x17\xc8^\xed5\x99b\x93)\xa6v\xdb4\xa5Q\xecX\x8eCP\xf1Z\xb0(\xf90\xe2\x90\x7f\xdc\x0c\xff\xbc\x1c\xfb\xf3\xb2(\xba\'h\x08m\x98\xa2\xf14\x128\x8a&ix\x96\xa5\x16\xb6\xdb\xf4\xb7[\x0f\x99*\xcc\xf8\xe9\'\':\xdchE\xb0B\xf73\x93\x1f\xcf\xfc\xe5\xfdU\x9f\xd1\xd93\x12\t\x80\xd5{\xd2a\x1d:Y\xf8\xcb<\xed\xef;\x1c%:\xf7\xeb/\xbeB*^\xfa\xf3\xb8\xe3\xf3\xbf0\x9a\xed6\x94\xd1\xd1\xc4\xe9\x0c9\xf1\xf6\xbc\x176\xe1\xfdC\xeb\xf2\xd8\xd3\x81\x80\xc5\xd9\x1d\xfa\xf9\x89\xa6\x907\x80\xec2:p\x1f\xfb\xd3x\xe4\xf3+\x94\x998\xd1\ ...
# (4, 'attachment; filename="planet.of.the.apes.(2001).slv.1cd.(4).zip"', b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x84\x10\xf1T\x08\xd7\xd6\x0f\xd5D\x00\x00\xed\x8f\x00\x00\x1c\x00\x00\x00Planet.Of.The. Apes.XviD.sub\x95}I\x92\xdbX\x96\xed\xbc\xccj\x0fP\x8d\x19nD\x0f\xfc\x89,"U?\x14\xa1Tc)\x0f\r4\x03E\xa4;\xd8\x00n`cV\x0cp\x039\xc8\x05p\xe0\xeb\xc9\xa5\xf82\xfe9\xe7^\x80TdU\xa5\xfdj\x84p\xe2\xbd\x87\xd7\xde{n\xfb~\xcf\xc2<?\xff\x9eEQt\xfe\xd0\x04\xfb&8\xec\x9e\xeaMw\xf7\xef\xff\xc6\x1fS\xbe*\xd2\xf3\xa7\xae\xed\x8e\xad\xfd\x1a\x17\x19~M\x92\xe8\xfc\xb5\xda\xd6\xed\xaaZ\x05\xbbc\xb7\xea\x82]\xbd>\xd6\xed\xb7.\xd8\xd4\xfbJE\x93$A\xd14\x9e\x9f\xdft\xc7n\xb3\nVu\xb0h\xd0\xfa\xf0\xa1~\xacVw\xc1O\xdd\xb2\t\x9e\xbaS\xd7\xd7\xadj\xa4q\xcc\x1aex\xfeT\xf7\xcd\xb7M\xbd\x9b\x05\xad\xca\x0e\x7f\xa9wu\x8b\x8fl\x83\xa6\r\xda\xe6%x\xea\x9b\x05\x1a\xbd\xac\xedcY\x11\xa1j^\x14\xe7w\xd5\xba\x0b\x96\xdd\xe6\xa1\x0b\xf65\x9bo\xab\xedk\x14\xc9\xa3d~\xfe=\x8fc\xb4\xde\xf5\xddK\xdb\xac\x83\x9f\xea\xea\xb0\xec\xffk\x86\xd6\xba]\xb3\xed\x82c\xb5\x9b\r\xcb\n\x1f\nN\x0f\x9bj\xd7\xa0\x89#>\xf9\\\xb7M\xbf[\xe3\xf3\xddrYo\xd6\x07~\x14m%l1/\xff\xa9\xc5\xa0\xe5\xc4\x8c\x8d\x0c7M4\xd6B\xbdV\x0by\x88n\xe7y\x96\x9e\xdf\xd6\xabY\xb0?\xacY\xaf\xb1wY\x81wE\xc4!q\xf2^\x07\xbfj\x02\x83\xb7\xdd\xb6\xdbUOM\xdd\xee\x86\'[\x9b\xe0\xb4\xe9\x16\x98\xa0%\x07\xbd\xa85\xde\x02#\xc5\xbfEr\xfe\xb2k\x82c\xbd\xedf\x01\x86\x86U\xd8\xa3|\xd5W\xcbf\xd8\xac\x0e\x8bnw\xd8\xae*\xff%\xe8\xabu\xbd\xaf\xd5\x81\x82k\x9d\x97X\xeb\x1f7\rz\x15\xac\x97\xe8H_\x9d\xb6\xcde\xb3\xaa6\xd5\xd0\x05}\xbdk1+\x7f\xad\xda\xfdA_-\x93\x98\x95\xca\xf9\xf9}\xb3\xdb4\x17~\xf2\xf0\xdc\x1c\xab\xed,X\xd7\xfd\x80I\xd9m\xaaE\x87\x95y9\xec\x1b[\x9a\x12K\xfe{1\x8f\xd3\xf3\x87z\x16<\x1e\xd1\xf6]\xf0q\xb7\xc73Xt\xdb`\x17\\\x9a\xedS\xd5\x9e43(\x88][\x84a\xc8Y\xd3/!\xbe\xf7{\x11\xa5\xd9\xf9S_\x1f^\x0e+\xf4\xe9\xa1\xba\x1b~\x08\xd8 6\xf6C\x154\xa7\x13\xbaqQ\xf9x\x8e\xb9-\xe24?\x7fl9#\xddS\xf3\x82G_o\xebu\xb0\xe4\x11\x18\xbe.\xfb\xe7j\x83\xcf[\x85\xb4D\x85$I\xcf\xef\xb0\xd7\xbb\xe0\xaf\x87\xdd\xbeo\xfa\xaamf\xc1\xaa\xd9\x06O\xd5\xb2\xb6\xbd\xdcv\xbb\xfd\xdd\xf0\t\xffVm\x8d\x83q\xda\xd6\xcb\x9a\xc5\xbe\xa1Y\xec\x8b]\xb3im\x18I\xc1N\xa7\xd8\xb9Z\xfc\x97z\xb7o\xf6\xd56\x187\xbf\xb7\xc2>\\\x82\xeeE\x8b\x82\xe28\x96E\x86\x93\xf2\xb5:\xb1\xa7\xdcf\xdb\x06\x83\x187.\xc6\xc1\xdd\xd0\xeac\xdb\xfa\xb1m6\xaa\x99\xc5\x19k\x96\xf9\xf9\x0b\xb6\xd1n\x7f<\xcc\x82]\xb5m\xbeqO\x0c\xd8XUP=`=\x9bc\xab3U\xe4s\xf6/Oc\xeb\xdf\x9fk\xcc\xca\x9b\x8e;p\xc7}\x82\xbd]/\xdb\xe6\x9bM\x90v[Q\xc6\xc5\x19\xe5\x82W\x81\xfe\xe5\x8b2\xc1\x8br\x1e\xa6|1CW\xd1\x9f\x8e\x9d|\xae\x83\xe5\xb1&\xbdh\xee\x82wK\x1d\x98\xe1\'\x0c\xf5\xd8\xa3\x08\xb6\xf2\xb6;\xde\x05\x9f:\xf4\xe9Rm\xb9\xb1\xd9\x1eZ*\xd8^>\xc7^!\x15\xc0\x9e]o\xab\xcd\xc1+\x0c_.\xf5\x8bM\x08\xf79W\xa1;V\xedJ\xb3\x87j8oe\x88s\xfb\xa1~\xf5}\xdb\x83o\xf2gu\xa9\xdepc\xa2d\xce\xf2E|\xfe\xe1C}7\xf0 \x1e1\xc5\x98\xf7\nK;nJ\x15\xd5\x96\xc2\xf8\xa3i\xb6fv`P\x9e\x0b\xb8\'\xad\x03\x95\xc0j\x0c\xf7\xcd\xdd\x9d\xfaS\xe2t\xfe\x1e\xce9\x9aw\xd5\x13(g\x1b\xbc\xa9\x8e\xcdr\xd7\xb5\xb3`\xd0\xe8@\x81\xda*\xd8rW\xa1F8\x8f\xe7%\xab\xc4Yx\xfeP]\xd8\xe7-\xd6\x05\xdb~\xdb\xac\xb5\xfe\xebn\x0f\xaayl\x1e\x8d\x0e\xb3\xa8>\x92`\xcf\xdcc\xa8\x87%\'\x07\x9d\xd0*\x90\x14\xed\xfbn[=\xb4\xf5\x1e\x1f\xfa\xaef\xc2-\x13\xceS\xd0\xa0/\x1cv\xf3\x80\r\xbai\xeb\xe0\xd0\xd7<\x05\xf8\r\xe7\x00\x1d\xde\xd4\xea\xc2\xa6~b\xa3V9\xe5\x8e\xc0\x03T\xe4W\x1c\xe7\xfbj}i\xf5I\xf5\x00#\xfc\xc6-\xdb\xad7u\xaf=|\xc0j\xd6G,^\xabu]l\x9ag;\xadlCc\xce\xb2\xf9\xd9z\xfdrX\xb66j\x9ct\x1c\x19\x91\xc1\xcd\xaaF\xd5]\xf3\xd0V\x1b\xefC\x96E\xac\x98cm\xbe\xacA\xec^0\xf4\xe6\xd1\xde\xe5\xa9\x06W\xa4\xc9yj\x87\x8b\xeb3\xd2\x82\xdc\x8f\x8d\r\xcd)\xf8Zo\xf1\x81\x19\xc8\x08\xf7\xfe\xa6\x01\xb9\x7f\x0c\xba\xc5\x12\x07be\r\x16 \'x\xf0\x0c|\xa9\xfb\x15\xa6S3\xd4-Q\x82\xdb\xa5[\xfa\xecz\xe7J2\xa4\x90\xeb\x83\x13\xd9\xd7\xcb\xc3]\xf0\xa1:a\xc7`\x19D\x83\x82O}\xf3Rc\x89A\x03\xbba\xc7\xf9y\xec\x96\xa4\x87\xeb\xee\xd4\x80\xa0\xb4\xfb\x1e\xcb\xc1\x199\xd5\xbd\xce!\x9b+\xd8j\x18\x85\xe7_@{z\ ...
# (5, 'attachment; filename="the.city.of.lost.children.(1995).eng.2cd.(5).zip"', b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x8e\x10\xf1T\xa0\xf7!\xcb&7\x00\x00\xec\x89\x00\x00;\x00\x00\x00The.City.Of.Lost.Children.1995.iNTERNAL.CD1.DVDRiP.XViD.srt\x8d}[\x93\xdc\xc6\x91\xee;#\xf8\x1f\xe0\'\xbe\x80s\x00T\xe1\xa6\xd8X\x06e[\xd6x%\xcbar\x8f\xc2\x8f\xe8n\xcc4<\xe8F/\x80\xe6\xa8\xfd\xeb7\xbf\xcc\xacB\xb6\xc4]o\xc4\xae\xccA#\x13\x85\xaa\xbc\xdf\x90\xbf}\x93e\xdfd\xc57\xbeJ}V\'\xef\xdf\xff{\xa2\x17\x9a\xb4\xca\x8a\xb7o~\xbc%\x97i\x9a\x93]\xb7\xbb=\xbc}\xf3\xf6M! \xee\x9b"O\xcb\xac\x8d t\xc1\x13\x88{\xfb\xe6\xe7\xe3\x94\x1c\xbb%Y\xd6i\xec\xcf\xc9z\xec\x93\xfdq\x18\x0f\xef\x96\xe40\xf7\xdd\xe9\x03\xd0\xb8\x88\x86\xa0\xea;4M\xda\xfa\xf2\xed\x9b\xcf\x04w\xea\x0e\xc9s\x7f\x1e\xaeK\xf2\x1fsw~y\xfbf8\'\xc7aI\xfa/\xc3\x98,\xfbc\x7f\xeayU>\xa2k\xd3,\xaf\x0c:W\xa4\x15\xa3\x9b\x92\xd7c\xb7&_\x86\xfd0\x11\xbeC\x7fY\x8f\xcb\xdb7\xaf\xc38&\xf4\xa8\xf3\xb4\xd2\xb5e\xdf\x9f\x0f\xbc\xc02`$\x04u\x91Y\x8ce\xea|C\xef\tH\xbc\xdd\xda\x8d\xf4\x9f\xebL\xef:%\xeb\xdc=\xf7\x87\xdb\xc3\x03\xaf\xab\x8aX\xca\xd4\x17\xceb\xa9S\x9f\xd3\xb2io\x8f\xdd\x97>\xe9\xe8\x7f.\x97[\x12\x9e_\x0b\xa4\xff\xc6\xe5i\x95\x17\x11\x92.\xb8\xb4\xaei\xff>\xad\xfd%\xb9^\xd2d\xec\x0eC\xbf$\xdd\x997k\x1diS\xce\xbf\x03\x8e&\xe2pi\xe3\x1b\x8b\xa3L\x9b\xbcR\x1c\xf3\xf0|\\\t\xd3\xef\x92\xdfO\':\xacqZ\xfa\x99\x97\xdfF\x04t\x7f\xe3,\x82:-=-\xff\x0f\xd3\xf9\xdd\x9a\xech\xfdOs7\x1c\x18*\xcf"XMk\xb7\xcf\xf5Y\x9a\x95DB\x9f\xfa\x9e\xb7nY\xe7\xe9\xfc\xdc/+\x1d\xf59\x19\x84Z^\xa7yTLy\xc0D\x80y\x91[L.u9\xbd\xe0\x0f\xd3\xf4\x92\xd0\xb9\xaeGZ5\x11Z7\x9c\x97\xf4\xed\x1b\xa2\x9c>\x99\x9e\xe4!\xdd\tO\xea\xfbQO%/"Z\xc2\xd2\xde\xa1\xad\xf0\x9c\xb7o\x88~W\x90\xcbu\xe9\x0f8\xd6qxZ\x03\xb4\x8b\xd0ts\xeb-4\xbdoA\'\xf7\xf7~I\x93\xd3-y\x9a\x07:\xcf%\x00\xfa\x08H\xf7\xb5\xa5\x05l\xd3\xb2\xa8\x84\xe8\xd7\xf9\xda\xd3\xf3p&D\xe9\xc3\xf9\xcb\xb0\x0c\xbbQ\xe8</#\n\x82hk\x83\xa2\xcc\xd3\xa6\xa2\x95\xff\xb5?\xf7D\x84\xabl\xf0~\x9a\xe7\xe1@DF{\xb1\x1c\xbb\xc3\xf4\x1aWS\x05T\x04\xd9:{\xb8%\x9dv\x86M \x8a\xbaM\xd7\x84y\x84(\xab\x9f\xdf\xbe\x89\x07\x14vw\x8f\x8d?\'\xd3\xb9_\x04o\xa4\\\xa0\xa93\x8b\xb7N\xdb\x82h\xeao\xfdy\xba\x9e\xf7\xb2\xc2g\xdaY^\x1d\xdeX0D\xba-\x9b4\xcb\xb6}*\xbf\xc92BI\xa7\xf7\x98\xbc\x9c\xa7W\xc0\xcfDz\xf4\xff\xcb\x0b\xf1\xf3\xb0\'.8\x11Aa\xd5\xe15\x95\x86\x19\xb6\xf5\x85EF\\Q\xd3j\x85tq\xca\xb4C\x84\xebuX\x8ft\xf0\xf2\xae\x87\xbe\xe3W=\xc7\xe5\x15Y\xc4\xe8 \xaa,\xc6\x8a\xd8\x84~\xfe\xb6Ov3q\xf5\x83yWZ\xd2\xfc\x95\x97-\xf2\x88\xad"l\x8d\xc5\xd6\x82\xe9\xe8D\xc7\xeb\xfe%\x99\xae\xab\xe0\xe8o\xbc\xd3\xcc\xab8\xa1\x7fL\xc47W\xd9\xfc\xa2\x88\xd8\xda\xb4-s\x83-/\x88c\x89|\xbe\xefG\x12\x1bK\xb2\xbb\x92L&\xb1\xb3\xebW:X\xc3t\x85\x0b8\x08\xa42\xa2\x8f.\xd4i\x0e*\x06\x99\xee\xe7\xebB\xdb\x9f|\x8b\x93\x07\xa5>\xd3:\x9eE\x04\xdeH\xae\xe1\x9dO\x13m\xa7\xec+?\xc42a\xe1\xe3c\x08kk\x97Z\x14\xc4\x84\rp\x8c7Z*\xa3\xa5\'^\xa6WP m\x1fT\xc0\t[x\xa3\xc3?\xe9\xab\x97\x01\x1f\xc0\xdb\xca\xe2\xf3i\xddf\xd8\xc8\xbe[\xfa\xaf\x0b\xcc\x14D\xf5\xda\x9d\xd7\xa4\xdb-\xd3x%\xfeY\x06\xd2_\xfb>\xac\xb7\x8a\xf8=q\xda\x1d\xfe\x8a\xd8\x99\x08\xe9p\x9d\xc3Z\x0f=\xd1\xe1\x02>\x1c\xa6\xb3\xc0\xd7\x11\xbeJ\xeb\xaa\xb6\xf0\xad\xb0\xeecr\xba.\x90\xa6\xcf\xa0\x11:lZ\xd4\x13\xf1.\x1f\xfb\xf4z&I\xf6\xd4\xafA\xb7\x14MDHg\xed,B\xd2\x19mE\xa4\x00\xa5\x06\xe1\x05\x19y\x1cNA\xc0\x12\x05\x05\x1c\x91;H\xcde\xae\xb58Hce\xf4\xce\xbb~\xdf\x91\x14\xe4=\xe7\x13\xc0\xda\xf68\xde\xb3\xbe\x1eie\xd2\xf6S\xf2L\xda=\x08I\x17\x99\x04xj\xbb[\xaeI\xcb:\x03w\x91|\x85\x92gQw\x99\xa7/\xd3KO\xdc\x98\xec\x89\xa9\x89}\xa0\x96\x89\x80\xe6#)\xd4\x8052\x0b!\xa9\xbc\xc5J\n\xa2\x04\xeb\x05\x1d\xd2w/X*hs\x13\t\x8c#\xb2\x08\x81Tw\x0c\xe7\x8b\xb4\x85n\xf8q~H~:\x13\xa1\xd0\x0b\x1dn\xa4\x8e?\x12\xa5\x90\xbcI\x13\x90\xf1\x19\xef\xcc\xfa\xd5EN!\x81^\x17V\xb6\x90xv\xe0\xdd\x1f\x86u\x85up\x1c\xfa\'\x81\x89dO\xb7\xf8\xd2\x9eZI\x1cZ\xe6\xac\x94\xbb\x11\x84D\xeb\xee\xa1D\xa6S2\xcd\x97cw\x06\xa5?\xbe\x83\xd9\xd1w\xfb#^IpF\xd2/\xc1\xb1w8}\xea \x14~\xe8WbP\x91\xd9\xdd*P\x91\xa0IP\x97\x95\xb3P\rA\xd50\xe5 ...
# (6, 'attachment; filename="antitrust.(2001).slv.1cd.(6).zip"', b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x98\x10\xf1T\x1c,\x8b\xb23f\x00\x00\xf0\xd9\x00\x00\r\x00\x00\x00Antitrust.sub\xad\xbd\xdb\x92\xe3F\x96%\xfa>f\xfd\x0f\xc8\xb4s\xce\x13\x93F\xdc\x81z\tK)\xab\xa5\xd4%2L\x99\xca\xb6\xd1\x1b\x18\x84"\xc0\x0b@#A\xd6\x11\x85\xf8\x81~\xe8\x0f\xe0C~O}\xc9\xb1\xf8\x8c\xb3\xd6\xda\xee C\xa5\xea\xa91\x9b\xb1\xe9B*\xe8\xeep\xf8e\xdf\xf7\xda\xbfge\xfc\xf4{^\xcc\x9e>U\xc1\xb6\xdb\xd7\xeb)\xfe_\xb0\xac\x83/\xcd\xb1\x0b\xe6M\xbf\xac\xa7\xff\xf6?~/\xc2\xe4\xe9\xf7\xa2,\x9e>\xf6\xd5\xba\xed\x82]\xb5\xef\xeb\xc9\xd0\xcdW\xbb\xeeK\xdd\x06\xa7\xe0aW\xcd\xeb/\xebes\xbco\xd8\xa3\x9ca\xe0p6K\x9e>\x1d\x82\xb6\t6\xf5\xbe\xaf\x82S\x15\xac\xeb\xb6\xda-\xeb\x16\xef\xa8\xd6M\xd0\xad\xd6\xf5\xb1j\xed5h\x9f\xb1W\x16>\xddv\xc7*\xe8\x16\xab\x1d\xa6P\x05\xc1\xbe\xc6\xf4\x96\xd5q\xbd\xac\x96]\xb0_u\xa7\xc6:d\xec\x10\xe6\x11;\xd4A\xb3\xa81\xee\xbe\xdat\xc1s\xb5B\xd3\xc9\xb0\xa8\x82y\x87>\'\xcep\x8d\x17\xa3U\x1b\xec\xeaE\xfdk\xd36\xbb\xaa\xb57\x87y\x89\x81\xa2\xa8\x1cW\x82\xab0o0\xd9\xbaU\x8b(\x8e\xd0"\xc6\xff~j\x82}\x13\xd4\xed\xaa\xd2\'\xb4\xcd\xf3\xba\x9ap\xc5\xf4\x9f\x9b]_\x1f\xd5#\xd6\xe4\x928}\xfa\xfd\x7f\xfee\xde<\xbd\rn\x83O\xc1{\xfc\xdfO\xc1\xcf\xc1\xc7\xe0\x13\x1b%%~\x0e\xd34\xc4Ba\xc6\x01\xe6\xb7\xe9v\xf5\x99\x8b\xdf\x04\x8b\xdd\xe1\xc1\xbe4K9X\x8e\xd6\xdft\xc7n\xd7\xe0\xdb\x02|\xdbjwnz,\xce\xae\xeb\x9bM\xd7v\xdbn\xbd_\xd5\xc3\xa9Zu\xf6\xa5j\xf5\xb0\xc3\x82\xa1\x19\xfe\xb8:\xe0\x83l\x8f\xc2"\xe4\'\x95a\xfe\xf4\xcd4\xf8\x8f\xa6\xdd\xf7];\xd1G\xac\xab\xc7U\x87\xf5\x7f\xe0\xbb\xb8\xe1\xf5s\xcd\x1d\xc7X\xcd\xa6\xea9G\xbd+h\xab\xa0\xaf7\x07,\xd9b\xd7=/\x0f7\x1c\xb7\x8c0n4\x8b\xf3\xa7\xbf.\x1an\xbek\xbc\xe2b\x05\xc7\xe0\xf6\xe7\x9f>\xbf9\x0c\xcb\x17\xc3t\x8bu\xf3\xdcv\xfb^s\x8bf\t\xc7\x08\x93\xe2\xe9S\xc7\xad8\xd7\xc1iS\xef\xb0B\xfbc7\xef\x16\x98T\xbf\xfb\xd2\x9c\x9f\xeb\xe9\xf0\xf6\x1f\xfe\x86=_\xec\x9a\xcb\xf7v\x1a3Ls\x8c\x19\xcdfO\x9f\x9b\x00g\xa2;\xe2\x00\xf4:\x00\xf8+\xf6!\x8aqlo\x1b|M\xbf\xab\xe7\xad-\xf1\xb1\xda\x07\x98\xe4\xa6i\x97\xd5\x863\x9d7\xfb\xfeh\xbf-\xeb\xa1\xafW\x9b\xea\xf2&\xed\x05\xce\xba\x06\x8dg\x05\x07-\xe2\xa7\xcf\xfbj\x15\xec7\xbbUu\xac\xef\xb1\x04\x0f\xd5\xae\xfa\xd2L\x86\xd5\xb2\xde\xad:\x9e\xa2\n\x1fQ\xf7\x87\t.\xa0\xba\x16\x9ck\x92\xe4O\xf8\xc3)Xt\xf3]\xb3it\xc2+<\'C\x8bi\xd965\xa7u\xf7\x8c\x9fNA\xf3\xb0\xb3\xafIc\\\xd8(K\xc2\xa7\xbb\xae9\xad\x0e{\x1c\x8e`\x1f\xec\x1fk<O\xd5\xb0\xea6\x87\xb6\xb9\xe7\xf9_\xd6\x93\x00\x0b\x86m=\xf3-\xf5.x\xe8\xdaf\xdd6+7\x93,\xc1\xc9\x8b\xf2\x9cc\xe9V\x05\x9bj\xddM\x83\xdb\xeaT-\xa7\xc1]\xb7\\4\x13^\xcfE3\x1d>\xd5\x8b`\xd3\xec\xd7\xcdF\xeb\xb3\xaf\xb9bg\xdc\xa6\x15/f\x1d\x1c\xb04G\xdb\xe1\x02\x97\r\xff[`\xdc\xea\x84+U/0\x1c\x7f(1m\xfcoY>\xfdT\x9d\xe6\xcd\x9a\xb7\xed\xa1\n^\x05\x9f\xbaW\xf8=\x9e\x85\xa0-\xf1\x0c\x13\xfay\xbf\xad\xd7\xd8t\xecfm?\x81\x94\xfd\x1e\x87\xe9\xec\xe9M\xf0!\xf8\xaa{\x08V\xb8\tZ\xbd\xca\xd6n:\xbc\t\xecD\xb5\xf5\xb1\x06%\xea[\x1d\x8e8\xe6\x05\x8b\x13\x1c\xbb;\x1e\xa3\xfa\x914\xab\xbeo\x1e\'8\x9a\xf8\x96\xb6\xdeO\x86y\x17\xdcN\x7f\x9e\xfe4\xfd<\xc5\x17?\xb4\xd5:\xf8\xf8[[m\xeb\xbd\xd6*\xe6~\xfd\x1e\xa7 \x97X\xbc-\x8fv\xdb\xe1t\xec\xb7\xbbzScU\x87\xe75\xe8\xd4\x19S\xb2\x1dXU\xf7\xb8\xc9\xea\x9a\x86X\x8e8\xc3\xd5\xf9\xc5\xc6\xdcw\x1b\x1cc\xb7\xc7\xf7XB\x9c\x8f\x01o=7\xa0\x82k\xdem\x0e\xbb\xac\xb1\x1bS\xdb*\xf4N9F\xa9\xd7\xef\xb7\x1d\xaed\xb3\xc6\t\x0eN\xc7nu\x98\x04\xd8\x97\x15\xf6\nGv\x8f\x936\x1c\xb1:}\xbdkt\x00\xbb9\x7f\xd40y\x8ec\x8b\x03X>\xd9D8\x8d]\xbdoy?\x83S\xcd;\xbd\x0e\x1e\xd6\xdd\\\xcc\x00\xf7\x83\xbd\x92Y\x8c\x0fH@\x92\x9f~\xa9\x16$"\xe0\x11\xdc\xba\x13\xb6hX\xf1\xa2\xad\x82]\xb7\x9a\x04\xc17\xd5\xee7u\tC\xect\x82[\x8e\xfb\x01\xc2P\x9d/W\xb6\x17\x91\xdd\xee\x9aS\xb5\x00\x87\xf0\xa4\xbc\tz\xecN\xfd\xd8v\xeb\xee\x01K\xa7\x0b\xbffC\x1c\xbc#n\x86\xc6\x8d\xb8\x96I\x1c\xcd\x1c\xb1\xc4\xe1\xd2qlI\x188\xad\x03\x0fN3,:\xbc\xee\xb9\xeaI\x94@\xc68\xbd\x83\x06\x88\xb9\x90I\x8c#\xf8\x06\xa7h\xd3\xf1\xd4|\xcf\x93\xc4\xce\xb6#=\xff\x13\xaf\xc5\x14\x9f+\x91\xb5\xbe#\xf5K\x92\x19?*\xc1 ...
# (7, 'attachment; filename="dirty.pretty.things.(2002).slv.1cd.(7).zip"', b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xa5\x10\xf1T5.?\xbb\x9eI\x00\x00\xcf\x9c\x00\x00\x17\x00\x00\x00Dirty Pretty Things.sub\x85\xbd\xcb\x92\xe3F\xb2-:?f\xf7\x1f\xa0=9\x93\xdci\xc4\x1b\xb8\x932\xe9\xaa[-\x95TU\xa6,\xe5\xb1]30\te\x82$\x804\xf0\xb1mS\xc8\x1f\xe8\xc1\xfe\x00\x0e\xf2{\xf4)\xfc\x8c\xbb\xd6r\x07\xc9,\xf59\xa7\xadMQIx\x04\x02\x11\x1e\xfev\x8f?\xf2\xd9\xec\xe5\x8f\xbc\x88_\xbeT\x8bn\xd9\x04\xcf\xfd\xa1\xd9\x07\xcfC\xbd\xef\x0f]\xb3\xaa\x82_\xff\xab\xea\xaaf\x18\x0f\x15\x9em\xf5\xd3\xffj\xd6\xdb\xbe\xabn\xfe\x9f\xff\x81\x9e\xe9\xcb\x1f\x05\xfe\xb3b\xd7\xednY\x07\xfb\xe0\xbba\xb7\xa9\xd7\xcb\x9b\xf1\xff{\xaa\x86u=\xf4\xcdM\xb0\xae\xb7\xc1\xdf\x7f\r\xc2Y\x98\xdc\xa2_Q\xe4/\x7f\x94\xd9\xec\xe5\xd3\xd0o\x9a\xb6\xbf\t\x16U\xb0\xa9\x83m\xb5\xea\x97\xc1\xe1q]m\x9am=vU\xb0\x1f\xaam\xf3\x14\xe0\xf5\xfd\xe2\xa9_\x04\xc7\xedm\x90\xf1\xd5e\x16\xbf\xfc\x81\xf1f/\xabe=\xb0\xf3s\x8f\xb7\x8c\xcfC\xb5_U\x03z<7C\xc5\x97\x01("(\xbe\xf2\xbf\xeb5\xc6\r\xaa\xfd\xb6\x7f7\x86\xb3\xe0\xf7]\xb7\xed\xf7x{\xfdZ\xaf\xab\xe0q]/\xaaus<\xbdc\xb70\xe4\x1bB\xcc\xf2[\xc2\x07?\xf7\xdd\xa2\xef\xf4(\x8a\xf9(\x0e\xcb\x97\xdf~\xf9\xf6\xcb\xb7\x1f\xfe\x16\xfc\xf9\xb7\xef\xf1\xdf\xbb\xcf\xf7\xdf\xfe\xfa#!\xe2$%D1\x9b\xde\x89O\xdb4\xea\x1cs\xd1\xc2$\x8e^\xbe\xdb=\xac\x9a\xee\xf1\xa9j\x83O\xd5\xbaz\xa85\xdd4\xe7t3|\xd9\x87\xe6\xe9d\xbfe!\xfbdy\xfc\xf2]\x13`\xae\x18S_q\x13<\xf6\x9b\xe7~\xa1\x81\xb3\xbc\x00P\x1e\xcf^\xee\xf0\xc2\xe6\x10\xdcU\xcbf[\xe9Y\x1es\x80\x1cC\x7fh6u\x1blw\xab\n[\xb4\xc2\xd2\xcd\x1b\xfc\x7f\x1d,\xfa\xc7~\xdf\x0f\xcb\xba\x0b\x0e\xc1\xbej\x9b\x1b\xf5\xcb\xd9\xaf\x88\x8b\x17\xf6z\xae\xbc#\xf7k\xa8\x8f\r\x06j6\xdb\x1a\x035\xc1\x12\xfb\x04\x04\xc0\xa6=\xd4\x8bf\xbd\x0b\x9ew\x9b-\x06\xde\x10\xa2\xd5g\x149\xf6=,\xa3\xf4\xe5\xe3\xed\xfb[L~\xa8\xdb\xfev\xfc\xf7\xe0s\xd5\xae\xeb\xe0T\x1f\xb0\x91\x02\x8d\xc3\x14\x1f\x13G\xb3\xf4\xe5\x1f5\xde\xf7q\xf5\x9f\xf5M\xb0\x02~`\xbc\x9b\xe0\xb4\xee\xf7\xf5\x8a_\x06\x10\x01\xa6\xe9\xcb\xfbEo\x13\xd8`\x1f\x81\xcd\xef0p\xf4\xef\xa5\x86\xd3~\xc4q\x19\xd9p\xcbJo\n\x84a\x98\xa5`\x92\x10\xb3\x8b\x93,}\xf9\xc4\x99\x07mm?g\xfc9\r5\x93o\xf8K\x9aa\x87\xe2\x0c\x18\xf8y\xdf\xe3\x8dM[\xf3\xc5\x87E\xb5\x0c~\xe9\xb1\x9d\xf5\x82\x1f\xf5\x8f=6\xd5\xa6\xae\x81\xca\x19\x07*\xb1\x07_\x08\xf9\xcc#\xf5\xd4l\xcf\x9fs;~\x1a\x9aE\x13\xe0\xb7\x01;{\xddX\x7f\xcc\xfe\x8fd\x96\xe0\x1b\xec\x11_\xc8\'I\xa2\'i\xc2\x03\x85\xa3\xf3Pq\x9a\xf8;\xe6\xaf%\x7f\xadW8\x1c\xfd\xcd\xb8k\xabC\xd5\xf5\xf8\xb6\xcdV\xa3&Y\xc4\xbeY>{\xf9\xdc\x0f\xf5\xf2\xf6\xf66\xd0\x0es\xda\xef\x04\x80\x01\xfeH\xf2\x08\xe7\xa0\xed\x81\xc4\x0f\xcd\xba\xe9\xd45\xc7F\xe2\xbf\xc0\xe7\xef\xfbys\x0c\xb6=\x8f\x7f\xdfo7\xbb\x9b\x11\x07)\xe8l\x84\\#\x14@\xcc\x8f\x0bL\x1a\'\x94\x84D\xfb\xde`;\xcf?i\xd0"\xe6|\n\x9c\x9c\x9f|\x93\x8c\x16\xe9\xa1\x960)\x81\x94?\xac\xb9\x8f<\xed\xcd\xb2\x1fI>.\xe3\x10Q\x96\xfe\xee\x92(\x97\xce0S-z\xdbp\xdd\xf9\xaf\xae^\xd9\xea\xe1\xa1@\xf0\xc6\x0fu\xd0b\x11\xda`\xbd[\x83\xee\x04\xfdc\xb7\xac\x82c\x1d\xe0P,\xaa\xeef\xf4\x8dR/\x1e\xe34\xc4\xb2\xdck~\x13\xe6\xe2\xa7\x88\x0f\xf0\xf8\x0b\xde\xd4\xcf\x07\xac6\xb1\xe4\xb5\xeejb\xfc\xedx_\x1f9CLf\xb3nZN3\x8d2`q\x1a\xe3\xdby2\x02\xee\x02\x90a\xb3\x1a\xe6\xf5\x1ag,\x98\xf7\xed\xb8\xaf7\xc0\x18\xd0V\xac\xf2r\xf7\xdaa\x9eF\x93vzo\xccU\xc6\x9eO\x87\x0b]\x82}\xb3\xa8\xd78\x9dx\x19($Wi\xdb\x0f\x8d\xe1{\x9a\xa4\xea\x80\x89~\xc0\xf3\xad(\xe8r7o\xda\x9bq\xc2Y<\xe5\xda\xa4q\xfe\xf2K?\xa0\xff\x1e\x84\xb5\xad;`\x12Vr]=\xe1<>\xdb<\xb1\xffZR|\xd5Zt7-q&\xff\xc8H}\xbf<\xf6\\\xf2%\x17RGx]\xcd\xfb`\xd5o\xc9p8\xd8\xf4\xbe\xac\xc8\xd8\xa7\xe4a\xab\xd6@\xf1\xa1~\xa8\x9f\x1f\x9a\xa5F\xcc\xcaXOK\xcc\x18\xd4\xe0\xb5Z\xf3\xabV\xbb\xa7\x06\xdb\x04\x16\x05\xbe\x15\xf4s~F\xd7\x9f\xf4\x8d\xf9\x8c\xd8\x94so\xff\x1b\xd0\x98\xf3R\xef\xc9C1\xbe\x10+\xf0\xb3>\x02\x1d\x8c\x96\xeaEE\xcc\xa5)b\xbc\xe8\x0e3\xfe\xaf\x1b\xa2\x05\xbe~\xdb\x8c\xf6\xcd@\x06l\xc6\x06\xaf\x06\xed^\x81\x87\xad\xfbw\xeaWb\xb9\x8a\x04\x18\xc0\tN_U\xa4\x05\x87\xcb\x92\xdc\xce\x18\x17b@\x7f\xf2)\xc7`\xd2\xaa\x ...
# (8, 'attachment; filename="bringing.down.the.house.(2003).slv.1cd.(8).zip"', b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xa8\x10\xf1T\xd9{\xe7\xe7\xbf\xba\x00\x00\xb4\xe8\x01\x00\x1b\x00\x00\x00Bringing Down the House.srtu\xbd[\x92\xdcF\xb26\xf8.3\xed\x01\xa2\x8dM\xcd\x8c\x15i\x89;\xd0\x0f#\xa3\x8e\xbaua\x8b\xa4\x89\x14\x8f\x8d\xde\x90L\xa8\nyCM\xdez\xba\x96\xd0\x0fg\x01\xf5\xc0\xf5h)\xb5\x8c\xf1\xefs\x0fO\x04\xba\xffsZ\x12\x89D8\x02\x81/"<\xfc\xf2y\xfa\xf5W\x8b\xc5_\xe4\x7fys\x9b/\x16\xc9\xcb\x97\xffw\xa2\x17\x8a\xf4v\xb1X|\xfd\xd5\xdf\x92_\x937\xc9\xeb$\xf9\x94$\xdf\xc9\x7f\x7fN>&?}\xfd\xd5\xd7_\xa5\xa1i\x91\xdf\x96U=mZ\xde\x96e\xfd\xf5W\xaf\xb7Cr\x1c\x92S\xb7\xfb\x16\r2oP\xdeVE5mP\xdf.\xea\xf6\xeb\xaf>\x9e7\xdd:9\xf6\xbbW\xb8?\xf7\xfb\xeb\xdb4z@\xb9\xb8-\xea\xf2\xeb\xaf\xde\x8f\xbb\xeeNZ\xec\x06i\xf0\xcb\xb8\xee\x92\xe3\xe9\xd0\xed7]rw\xe8\x93K\xf2\xd8=\x8c\x07\xca*\x82,i\x1aw\xb6\xcc\xb4\xb3\xef\xeeo\x93}\x8f\x7f\xd0\x98\x8dJo\x94\xddV\x8bi\x87\xcb\xe2v\xd1\xc8\xcf\xbf\x0c\xc7\xed\xb0\xbbMV]r\xe9w\xf2<\xf4?4\xaf\xbcyq\x9bf\xd13\xab\xdb\xac\x90\xd7\xfb\xb5?rdj\xbfS~h\xa2\x075\xb7u\xc97\xbd\xdb\xf6\xeb\xe4\xe10\xec\xfaC\xf2cw<\x8e{\xf9\xdbx\x1a\x92\xff\x1a\xf7\x87nu\xe6#\x1b\x17\xd4\xdc6\xc5\xf5\x91\xa9\\\x931\xcf!h5.\xf7\x83t\xf5\xb9?\xc9\x7fW\xe3\xa6{\x1c^\xbdb\xf3V\x9b\xf3\xee:+\xa7\xcd\xb3\xdb\xbc\x95\x9f\xdfk\x07\xd6}\xb2\x1c\xb6\xc9\xf8p~z\xee\xf7l\x9b.\xbcqv[\xc4\xcf.\xe4\xd9\x02\x97\x17\x7f\xef\xef\xbam\xdf\xc9\xab\xbc\xb8M\xee/\xdd\xb6KN\x83\xb6N\xbdu!\x8f\x8eZ\xd7\xb7Y\x0ep\x0c\xc9\xb0\xeb\x9ed\xac\xb7\xfds\xb2\xef\xd6\xcbq\xbbN\x96\x87a;\xac\xbb\xfd\xa9\xdf\'\xe7\x9d\xbdG\x9a\xb9\xb4\xfa6\x8f_D\x06\xb4\x92\xae^\x92\x93\x8c\xe7f\xdb?\xf4\xa7n\xbb\x1f>[?ro)#\xb8\x98\xf6#\x15\xe4\x942\xc0?j\xbf\xfb\xe5p\x9b\xbc\xf8{\xf7\x8f\x7f\xf6\x87\x97w\xc3a\xfbB\x05\x14A@\x8a\x11\x8f\x04\x14\xb79\xbe\xe5\xa7^\x11#\x83x:\xcbG\xecW\x0f\xc3\xb1\xdbw_\x7f\xd5\xed\xc7\xfd\xb0\xdb\x8f\xc7\xd3\xad\xe0i\xbf\xea\x0e\xe1\x85J\x97Z\xcc\x067\x95\xe1i\xe4\x85:\x99l"q\xd3m\x9e\xf6]\xb2\x1b\xbf\xa8\x98\x95\x88\xdd\r\xc9\xc3x\xe9\x9f\x92\xe3e\x94[\xe4\x0b\x12ui\xe5B\xdb\xdb\xbc\x9a\n\xcd\xd2\xdb\xac\x96w\xfdi\xd7\xcb\xe4\x82\xdc\xff\xba\xef\x0e\xdb~\xaf\xc8N\xeb\xd02/g/\x99\xd7\xb7m&\x1f\xf3\xd3s\x7f\xd0\xb9,C%\x8f\x97I\xf1\xd4m\xb5u\xe3\xad[Ai5i]d\xb7\x8bB>\xde\x9bn3b\xe9\x90\xc1\xf92\\z\x19\xefU\xb7\xd7N;F\xe5\xde4\xea\xb4\xacCE#\xef\xf4vx\x96\x07\x1e\xfb\xe5^\xe0\xc6\'f\x8eM\xaeU\xd1\x13K\xc1\x83<\xf1\xf7\xf5\xf9\x14:,\xd8\x92\x07\xaf\x9349\x1fF\xe9\xfev\xbct\xaba\xdb\xddR\x96#U\x9a\xcez\xdf\x08R\xa5\x03\x0f\xe3\xc3\xb8\x95\x0eS\xd8\xb1O\xbe\xfej5n\xef\xc6\xe7\xee(BDz\xb2\xba\x8c\x87\xe1\xe9\xf9\xac\x02\x1d\xac\xd2>\x06k\x99\xdeV\x8d \xf2\xf1\xd2\xcbp&\x0f\x1d%\x8e\xcb\xe1\xb8\x01\x06e5Xw\xd2\xbd\xf5\xf0y\xfc\xfa\xab\xe119\xca[?=\x0f\xf6\x952\xc7\xb2\xc8\xa9\xa3\xb7.e\xa8r\xf9\x0c\x1f\xb6\xc3\xd3\x80.\xae\xc6\x0bf\xd3\xbe\x97\x9e\nr^%\x14\xe0X.9\xb4S\x01\x95\xec\x0e2\x12oe\xc8\xe4\xfb\xee\xc6u\x12\xde\x11\x8b\x8a\xbc\xbb\xac\xa32\x882-O\xf6\r\x1c\xc2h\x1b\x8d\x1b\x169,.?\xed:A\xcby5\x10\xa8\x18y\x99\x0b\xba\xa4\xab\x08\x03l\x86Y0\xfd\xf6rA\xbe\x05\x86\xfe\xc3\xa9;\xe8(\xe5i\xb2\xedO:\xc2\xb5\xb7+\x05\x9d\xe5\xb4]+K\xb3|\x80\x01\x8f\xc6\x1b\xf4\xf2}6\xe3J\x1e\xd9\'\xdb\xee\xd8\xcbO\xfb\xa4;\x89\xa8\xa3@R`u\xea.\xa3\xf6\xa6q\xa9\xad,\xe7\xd3\xded\x8b\xdb\xb6\xc2\xaa-\xef\x7f\xb8\xc5\x9c\x1c\xf1\xf1d\xb1\x1e\x1ee\xf1[uO\xba!\xb6AB\x06\x14\x16\x13\t\xb9,\xc0Xl~\xee\x1e\xb9\x1f\xbez\x95\xec\xba\xed\xe7^F\xa3\x13h>a\xc5N\xd2&K>\xdb^\xb9\x08\xa2\xa4e\x13u&\x97e\x07+\x9e\xec\x8f\x03^I&\xf3qD\xf3\xe3\xa5?mu\xd9\xcbSo\x1e\xaf/\x19&\xf4\x02P\xf9Q\x16\xad?d\x9d\x1d/\x18\x88i\xdb\xcc\xdb\xb6\xf2\xda\xd3\xb6\x85m\x93\x7f\xef\xee\xa5\xcd~|\xd6\xaf\xfb\x9f\xd6N\x02.7\xc4\xe6\x7f\xc9\xb2\xdbv\xa2\x8e\xc8\x85\xe2\xb6\x84:\xf2\xe6\xd7\xd7\x7f\xff9\xf9\xfe\xf5\xa77\xef>\xcd\x9aTQ\xcf\xe5\x82\xc0\n\xdf\xf6\x07YI\xb7\xfd\xe1\x1b}D\x11\xee\xcf\xf3\xe8\xab\xe5x\xf5\x16\xcb\xcb\xcb\xe4\xfbq)\x13\x1f+\xc2x\x9b\xdc\x8d\xc7\x87q\x95|\xe8\xf6\xab\xfe \xdb\xee+\xdc\xf1\xbb \xc4 ...
# (9, 'attachment; filename="cradle.2.the.grave.(2003).slv.1cd.(9).zip"', b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xab\x10\xf1T\r\x8a\x9eGku\x00\x00\xdf \x01\x00\x16\x00\x00\x00Cradle 2 The Grave.srt\x95\xbd\xdb\x92\xdc\xc6\x92%\xfaN3\xfe\x03\xd8\xcf\xa9:\x89;\xb0m\xaciR\xab\xcfn\x89[\x14M\xa4\xd8\xc7\xf4\x86\xaa\xc4\xaeB^\x80\x9a\xbc\xf5\xd9\xf9\t\xfd\xd0\x1f\x90\x0f\xfc\x1e}\xc9X}\xc6\xf1\xb5\xdc#\xe0Iif\xce\xbcH,$\xc2\x03\x08xx\xf8uy\xfa\xfa\xd5r\xf9\x97e\xfa\x97\xacY\xb4U\x91|\xf3\xcd?\'z!_.\xb2\xb6}\xfd\xea\xb7n5\xae\xbb\xe4y\xba\x0e\xdb\xf5\xa6K\xd6}r<m\xba\xf5\xdd\xebW\xaf_e:<\xfb\xcb\xb2Y\xd4m\x19\x87g\x7fI1\xbc~\xfd\xeaCw\x19\x92C\xff\x06w\xe7zw\xfe\x97\xb4YdM\x16\xef\x96\x0b\xed\xa2X6\xaf_\xfd?\xc9t\x19\xbb\x97\x93L\xb2\xeb\x0f\xc7\x89\x93\x14aXV/\xd2\xaat\xc3\xe4\xa1\x8bR\x86\xfd\xcb\xd3~\x90\xbb\x9f\x9f\xfc\xb3\x95qX\xb3\xa82?,O\x17\xcb\xa5<\xcc7\xc9\x7f\x1b\xfe\xf9]\xb7N\xee\xa7d5\xdd\xef\xfb\xc7\xee\xed\x7f\xfb\xbf\x86\x7f\xc6/\x1f\xc2\xfb>O\xc7\xfd\xba\x1f;\xd2\xac\x02M!\x91\xd6KO3\xd7\xf7\xfd&y\xdf%\xbb\xb5<\xfc)9\xec\xf0\x02\x9c\xe5\xe3\xbe\x7f\x19\xa7;\xa5\xfe\xfaU\x1d\xe9\xe4\x8b\xb2\xa8=\x9dbQT\xf2\xc62\xe6\x87]\xb7\x9b\x92\x03\xfe\xd3\x8f\xf2\x1c\x87\xcd\xe9\x10)4\x91B\xb1\xa8\xf2\xd4S\x90E\xc9jR\xf8\xbd\xc7\xe7\xda\xac\xa6\xe4\xd2\xad\xfb\xfbn\x9b\x1c\x8e\xe7n\x9f\x0cc\xb2\xe9v\xe3\xa0\xc4\xe4\xc6q8L\xbat\x8b\xe48%\xe3\x90\xec\xa6u\xf2\xbc\x9f\xee\xb7\xfd.\xce\xd9\xc69\x9bEY\xfa\xefW\xa4\x8b\xa6\xa8\xed]?\x81Nr\x08o++\xd2\xcb\xfc\xb2\xc2\xdb\xc7\xe9.\xf9\xd8\'\xe7a5\xec\xf4\xdb\xa6K\xa5Y\xfc%\xad\x16m63`\x01&\xc9\x0ba\xb0\xcf\xfdv\xad\xab\x9f\xa6\xe1\xe6l)/]\xb9\x9b\xb3T.\xc8\x03\xfc\xdb\xb9\xdb\xda\xcdY\xb8\xb9\xc8\x16u\x93\xbb\x9b\x0bY\xb2\xb4\xe1W\xde\x0f\xd7m\'\xfc\xb9KF\xf9\xdf\xf3\xbe_\xcb\xfb\xe2\x97\xcf\xdd\xb5O\x86]\xff\x96\xb4\xf2H\xab\x10Z\xa5\xa7U-\x96\xb5\xd0\xfav|\x1c\xfa\xe4\x97\xee?\xb6\xc3x\xd0\x070\xbe-\xc1,m\xdb\xc6Ar\xa1\x14\x8e\x94\xa7\xfdm%\x0b\xb5\xed\x9e6S\xf2\xb8\x17\x96\xe9\x93\xc7i/\x83?\xf2Qd\xdf\r\xbbdu\x1e\x1e\xbb\xed$\xff\x98dO\xac\xfac\xf7\xa5W\xfae\xa4\xdf,\x9a&u\xf4\x8b\xa5pU{\xb3\x1a\xc6\xb9\xd5_\x96\xed\xa2\xaa\xe6\x9b\xab\xbf\xa4\xe9"\xcf\xe53\xbc\x13V\x11. c\xe8[\xd7aL\x9a\xc9\x98\xc2\x8f)\x16\xcbF\x16\xf8\xc3\xbe\xdfl\xfb\xe3\xb4 \x93\x1d\x86\xe4\xb9K.x\xa9\xa3\x91h\x02\x89\x0c|\xdd8\x12Y)\x0f-O\xf5N\x06\xae\x87\'Y\xff\xfb\xee,_\x1a\xacr\xec\xefm\xe1\xdb8\xbe\x92\xdbk?\xbe^\xb4x\xec\x1f\xfb\xfb(`\xb2e\xb8=\xcf\x16y\x9b\xb9\xdbe\x9b\xa4\x98\xee\xdf\xa6\x17|\xecu\xff8\x9d\'|\xe0dH\xae\xc7\xfe<l7\xca\x91Y\x1ai\x94\x8b\xba\xf6+\x95\x0b\x8b6K\xbcuw\xd6{\xb3xo\xbd\xc8\xf2\x9b{\xdb\xc5\xb2\xaa\xc0I\xdf\x8bd\x91\x05z\x9e\xce\xfdJv\xe0q\x10qc<F^\x132y$#\x1f\xa7\\:2\xc2\xbbe&\x8b\xf8q:\xef\xbb/\xc2\x0e\xc2#\xdc\xc3\x83\x8c\xfc\x16\xc4F|5\xfex\x95\x1f\x9f\xecW\xae^V\x04\xba\x85\x88\x99\xac\xf5t\xcbE\nq\xf5cwQ\t3\xe9\xea\xef\x92\xc3y\x12FX\xf5[[\x8e2\xd2\x10\xa6m\xfd\x17(D\xae\x96\xf2\x81\xbe\xdd=w\x9b\xe4|\xe8\xfbQ\xdes\x1c6\xd3\x16_\x04Ov\xee\x17\xaf_m\xa6\xc7N\xde\xf9\x9a\x1cD\x08v[\xe1\x95n=\xea\xf7\xcd"[\x96\xf9"\xcd\xfc\x02\x96\xb5\x08iY\xec\x8f\xc7\xee<\xec\x16\xc9\xaa\x03\x7fq\xf5\xb6ka\x12y\xde~\x14Z\xd3\xf1\xf5+\xe1\xba\xa3\x1c\x00\x83\xca\x98\x97\xee \x02l\xbb>\xad\xe4E.\xb2\xa3\xc2a\x15\xf9Yh\xd7\xcby9\xea\xbf,\x97\xc2\xcf\xd8\x90\x9dlC\xd9\x84\x87\xe7n\x91\xacemv2z\x97L\xcf{\xae\xceqx\xfd\xea\xeb\xf51\x0e\x17\x1a\xc5"K+OT\x04\x18\x8e\x19\xb0\x0b\xbe\xffQ\x18ON\x9a\xe7\x8e\xaf\xd0\xf3\x95d\xdb\xef\xe4\xf9\xa7\xc7\xad0\xc7\x91K\x03\xb1+[\xa8[\xdb\x04m\x98 \xcd\x17\xcb\x9b\td\x17V\x8d|\x9fO\xd3n\xf7\x0f\xde\x9c/\xe3\xcd\xe5\xa2\xc8K\x7fs-, \xbc\xfdQ$\xcb\xae\xdf\xddw\xb2\xe3^\xf6Gy\xcfg\x91*{9(\x84\xc2\xa7\x01\x8b,\xa2\xf0\xbc\x97\xe5T\x92i$Y\xcbt\x8d\'\xd9.\xca\xaa\xa4\x84\x1fv\xdd5\xb9v\x14}\xdf$?\xcb\xda-\xf0\xa2rYY<\xcf"\x95vQ\xbb\x9dRC\x967\x10Orr\xfcU\x1eMX\xe8e+{e\xf3&\x1c;y\x1e\xc6\xca\xad\xad\x93\xe4r!\x17\x9e,0\xa5\r\xe5R,\xc0&\xb7\xef\x01Q\x1fD\x95\xf0\xa5\xec@\xd5H\x8aH:_4\xd5\xcdc\xc9\x8enR,.\x8e\xc3}w\x01\x0f@\x98\xbe\x17\x1eY\t\'No\x92\x0f]"\xa7\x04T\x07\xb9\x ...
# (10, 'attachment; filename="death.to.smoochy.(2002).slv.1cd.(10).zip"', b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xae\x10\xf1T:?\xcd3\x8b~\x00\x00\x86\n\x01\x00\x14\x00\x00\x00Death To Smoochy.sub\x95\xbdI\x92\xdc\xd6\xb6-\xd8O\xb3\x9c\x03\xd8\x0f\x85\xb9\x03p\x14\xbfC\x0b^\xeaJ\x14\xc5\xc2\x18\x14\x9f}\xf6\x10\xe1P\x04\xbc\x00\xfc{\xf5R.\xc4\x04n\xe3\x0e\xc0\x1b1\n\x0eBC\x89a\xe4Zk\xef\x03wR\xbc?\xf3\xbfB\x08:\xce9\x00N\xb1\xeb\xbd\xf6\x9f\xf98{\xf83\x9f$\x0f\xbf\xbd\xf9\xb0\xb8\x88\xae\xdf\xbc{\xf7\x8f\x9f\xff\xe7\xb3\xff\xfb\xff\xfa\xb3\x18\xc7\x0f\x7f\x16i\xf1\xf0~]O\xa3c\xbd\xd96\xcb&Z\xd6\x9b\xfa\xb6\xb9\xbc\xbcD\x8br4z\xf8\xb3\x9c\x8c\x1f>WOu;\xab\xa2M\xfd\xac\x7fS\xed\xd7\xcdS\xdbD\x1f\xaav\xda-V\xf7\x1c\xab,0\xd6x\x94\x8c\x1e^v7\xebn\xda\x1d\x17M\xb4\x8f\xba\xe9\xb4\x9a5\xa1K}W\r\x9d*\xf6B\x87\x04\xdd\xc6\xa3L\xef\xb0\xd9V\xfb\xc5\xacZv\xd1\xbeZFm5[\xccv7G\xf4\xea\xabe\xbdn\x8es\x0e\xd0m\xd7\x9d\xfd\xb5\xef\xa6\xcd\xb6F\x87\x0b\x0e5\xe6\xd7\x8c\xc7\xc5\xe4\x01\x1dW\xebfV\x1d\xdaz\xc6\xde\x91\xfe\xa5\x96}[E\x87z\xb9\x985\x17\xd1\x7f|\xa9x\x9cc\xa4\x18#\xbd\xad6\xdbnU\xcd\xba\xe8\xaa\xbd\xab\x17]\xf4\xbe\x99\xd7}\xd3F\xaf\xd7M;_\xd4\xd1\xebf\xba\xb1>%fy\x9c\xa4)>\xc4\x1f\xd6D\xeb\xea\xb0\xc0\x13\xbah\x83/\xaa\x17\xcd\xbca\xd3\x04\xf3\x89\xff\xe6\xd9\xc3\x87z\x13\xcd\xea\x8b\xe1\xf1\x9c\xf2q6\xe6\x94\xe4\xa3\xe2\x7f?R\xff\xb1C\xdfh]o.\xa2m\x17M\xeb\xd9f\xbb\xe7O\x1c#\x1f\xf3\x11y1~\xf8\xb4\xa9\xef\xa3\x9bj\xbd\xbf\x88\xe6\xdd6Z\xf2\x9bo+\xccm\xb4\xd1(\xef\xa6\xd1\xb2\x9b\xae\xebh\x8a\xb1\x17\xf5\xa1n\xf1\xc96\x06\xbe\xff\xcfq\x91\x96\x18cx\x81\xe6\x9eo\xd0,\xeb\x96\xb3\xf0Tc\xb9\xea=Gk\xbb\xbb\xea\x9e\xdd\x8a\t\x97\xa1(\xe3\x87\x1f[v\xc3;.\xeb\xa7z\xd6\xf5/\xd7\xbb;\xffe\xab_\xd4\xbc\xe4\\\x97Yf\xcd\xeb9\xb6\xcdM\x13}\xf9\x82\x07\xee\xb0\x1b\xf1\x94M\x1d\xed\x9e\x9a/_|\x80/\x87\xbbuu\x83\xf5\xdb\xae\xeb\xe3S\x13q}\xbb\xe8FM8b\x99\x95\x0f\x7f\xc6\xa34yx]\xaf\xf1C\x1c\'xD\x9c\x8c\xca\xff\x8f\t\xdd\xd7\xebY\xbd\xc4\x8e\x8a\x96\\\xa78\x89\x0b\xf4K\xb1\x19\xde6\xf3\x8e\xdb\x99\xed\xba\xcd\x16\xcf[\xd6\xcb\x1b~u\xd3\xffUG\x8f\xf8\xfd\x18a\x92l\xd7\xd5m\xd4\xdd`$\x8e\x91&\x13\x8e\x81\xd9\x18\x9e]a%\xd8\xb4\xda7\xb6Z\xb8\xcd\x17\x9c`\xbe\xf1\xb5\xdb&z\xac\x16z\xca\xba\xbek\xabEt\xd3\xe1\x81[\x1bo\x82\x91\xfe\x8c\xf3\xb8|x[\xcf1\xe5\x1ak[c\xc6\xd0\xea\xb0\xc7\x11\xee_\xb5Q\x8b\xa7\xef\xec\x9f\xf8\xfd\x18mwS\xb4\xd2G\xe5z\xa1<O\x1e\xb0\x7f\x9e\x1alo\xdfE\xbcY\xe0\xe7?\xb1\x93\xc7\xdf\x99\xa9\x063\xd5\x7f\xffgv-\xb1\xd7\xfeLF8\xc8\x1f\xab\xb9\xc6\xdc\xf2\xf7d\x14\'\xfc\xbd,\x1e>\xe1m\xb0\xd7\xe7\xd5\x8cw\x8f\xf5iK\xf5ab\x9b\xe7\xd1\xdb\xea\x88E?L\xeb\xc5\xbc\xe1qH\xc6<\x0e\xc9\xb8,\x1f~\xad\xee92\xb6\xe0|\xb7\xe22\xb5\xd5@\x8b\x86\x13t\xdb-\xd5-\x1e\xa7\xe8\x16\xe7\x93\x87w7\r\xb6\x89\x9a\x1f\xb1\xdc\xdbu\xd5^`\xe1\xa2\x03\xcfv;S\xeb$\xe5C\xd2\xd1\xe4\xe1\xcd\xd5\xa7\x0f\xaf\xfez\xfb*\xfap\xf5\xf6\xe5\xbb_\xdf\xff\x1c\xb5F\x03\xfa}\xf4S\xb5\x9ebq\xaf\xb7\x98\x82\xe8=\xd6o1\xeb\xda\x1d\xfb\x97|\xc9t4J\x1f^t\xd1B\xef\xb9\xecf\xd1\xefU\x8be\\\xd4\x1b\xac\xe2\x06\xcb\tZ\xf8\xbc\x1fZlj|\xa5N\xe2\xb6[\xec\x9ec\x9ct\x14\x8f8N1z\xf8\xa9\x8a\xee\xbb\xa7\x1a\x0f\xdas\xa8\xc6)\xa9\xb5\xe2~I\xc7i\xf6p]\xef1\xe8e\xff\xc3K\xec\x84\x03\x08\x14\xbf&\x1d\xe34\xfd\x99b\xc7c\x93\xe0\xf0\xf1\xf4l1\xefx$(c\xdfq\xeb\x91\xcaF\x9b=\xdeq\xd5m\xea\x85\xbaas\xa1\x1b\xe6\xe2\xe1\x1ak\xb4\xd9\xe3\xc5@\x8a\xc1\x08\xa2\x1f\xdew8\x97\xb7\xd5\xa2\xdfW\xb3\x1d\xb6\xd4\xf2\x02g\x9f[\x8e\xab\xb9Zc\xe9\xbau\xa5A\x12\xf2\x814M\xe3\x87\xebm7{\xd6\xffp\xbd\xdaaa\xa3j\xbe\xed\xf6\xf3\x8e\xb4\x12w\x0b\xb6)\xf2\x87\x97 7k\xb1\x15\xac\xc8\xa6\x06\xcdo\xd0v\xdam\xaby\xdb\xd8[\xa5%\xa7d\x823\xfc\xcf\x17\xaf\x9eEW\xebz\xdb`\t\xb1\xef\xb6\xb5\x1aL&\x9c\xfb\x0ck\xf7Ku\x888\xc8\xdf\x19T\xff\x0eL\xe3\x96\xbc\rG\xb3{\xdc\xcd@}\xf4*"\xb6i\x86Wy\xb5\xe4\xaa\xeaX\xdev\xa4\x86\xcbn1\xc7\xd4\xe2|\xe3\xed\xb4\x00\xeb\x9a\x0bb\x9c1\xcdG\xd8\xf0i\x8e\x0f}\xdd\xadw\xab[\x1c\x0c,\xd5\xb4&1\x08\xecA\xab\x95\xa7\\\x8d"\x1d=|\x8f\xe1D\xf8\xaa\x08\xef\x83\xa9\xc5\x96\xdan\xfe \xb1\xde\xe9\te\x8e\'LF`\ ...

# %%
import sqlite3
import zipfile
import io

# Connect to database
conn = sqlite3.connect("opensubs.db")
cursor = conn.cursor()

# Select a sample row (or multiple rows)
cursor.execute("SELECT filename, filedata FROM subz LIMIT 1;")
row = cursor.fetchone()

filename, filedata = row

# Use io.BytesIO to read blob data as a file-like object
with zipfile.ZipFile(io.BytesIO(filedata)) as z:
    # List all files inside the zip archive
    print("Files inside zip archive:", z.namelist())

    # Extract the content of each subtitle file
    for sub_filename in z.namelist():
        with z.open(sub_filename) as sub_file:
            subtitle_content = sub_file.read().decode('iso-8859-1')  # ISO-8859-1 or utf-8 depending on encoding
            print(f"\nSubtitle file: {sub_filename}\nContent preview:\n")
            print(subtitle_content[:1000])  # Print the first 1000 characters for preview

conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[8], line 10
#       7 cursor = conn.cursor()
#       9 # Select a sample row (or multiple rows)
# ---> 10 cursor.execute("SELECT filename, filedata FROM subz LIMIT 1;")
#      11 row = cursor.fetchone()
#      13 filename, filedata = row
#
# OperationalError: no such column: filename

# %%
import sqlite3

db_path = "opensubs.db"
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# List all tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables in the database:")
for table in tables:
    print(f"- {table[0]}")

# Get schema for the 'subz' table (and others if found)
print("\nSchema for 'subz' table:")
cursor.execute("PRAGMA table_info(subz);")
schema = cursor.fetchall()
# schema format: (column_id, column_name, data_type, not_null, default_value, primary_key)
for col in schema:
    print(f"- Name: {col[1]}, Type: {col[2]}, PK: {col[5]}")

conn.close()
# Out:
# Tables in the database:
# - subz
#
# Schema for 'subz' table:
# - Name: num, Type: INTEGER, PK: 1
# - Name: name, Type: TEXT, PK: 0
# - Name: file, Type: BLOB, PK: 0

# %%
import gzip

metadata_path = "subtitles_all.txt.gz"
num_lines_to_check = 60 # Look a bit beyond line 55

print(f"--- First {num_lines_to_check} lines of {metadata_path} ---")
try:
    with gzip.open(metadata_path, 'rt', encoding='utf-8') as f: # Specify encoding if known, utf-8 is common
        for i, line in enumerate(f):
            print(f"Line {i+1}: {line.strip()}")
            if i >= num_lines_to_check - 1:
                break
except Exception as e:
    print(f"Error reading file: {e}")
    # Try a different encoding if utf-8 fails, e.g., 'latin-1' or 'cp1252'
    # try:
    #     with gzip.open(metadata_path, 'rt', encoding='latin-1') as f:
    #         # ... read lines ...
    # except Exception as e2:
    #      print(f"Also failed with latin-1: {e2}")

print("--- End of file sample ---")
# Out:
# --- First 60 lines of subtitles_all.txt.gz ---
# Line 1: IDSubtitle	MovieName	MovieYear	LanguageName	ISO639	SubAddDate	ImdbID	SubFormat	SubSumCD	MovieReleaseName	MovieFPS	SeriesSeason	SeriesEpisode	SeriesIMDBParent	MovieKind	URL
# Line 2: 1	Alien 3	1992	English	en	2004-10-31 23:54:23	103644	sub	2	 Alien.3	11.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/1/alien-3-en
# Line 3: 2	Identity	2003	Slovenian	sl	2004-10-31 23:54:23	309698	sub	1	 Identity.DVDRiP.XViD	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/2/identity-sl
# Line 4: 3	Ghost in the Shell 2: Innocence	2004	English	en	2004-10-31 23:54:23	347246	srt	1	 Innocence.2004.DVDRip.XviD	23.980	0	0	0	movie	http://www.opensubtitles.org/subtitles/3/ghost-in-the-shell-2-innocence-en
# Line 5: 4	Planet of the Apes	2001	Slovenian	sl	2004-10-31 23:54:23	133152	sub	1	 Planet.Of.The. Apes.XviD	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/4/planet-of-the-apes-sl
# Line 6: 5	The City of Lost Children	1995	English	en	2004-11-01 20:11:53	112682	srt	2	 The.City.Of.Lost.Children.1995.iNTERNAL.DVDRiP.XViD	23.976	0	0	0	movie	http://www.opensubtitles.org/subtitles/5/the-city-of-lost-children-en
# Line 7: 6	Antitrust	2001	Slovenian	sl	2004-11-02 21:30:28	218817	sub	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/6/antitrust-sl
# Line 8: 7	Dirty Pretty Things	2002	Slovenian	sl	2004-11-03 11:58:18	301199	sub	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/7/dirty-pretty-things-sl
# Line 9: 8	Bringing Down the House	2003	Slovenian	sl	2004-11-03 12:04:20	305669	srt	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/8/bringing-down-the-house-sl
# Line 10: 9	Cradle 2 the Grave	2003	Slovenian	sl	2004-11-03 12:06:36	306685	srt	1		23.976	0	0	0	movie	http://www.opensubtitles.org/subtitles/9/cradle-2-the-grave-sl
# Line 11: 10	Death to Smoochy	2002	Slovenian	sl	2004-11-03 12:09:01	266452	sub	1		23.976	0	0	0	movie	http://www.opensubtitles.org/subtitles/10/death-to-smoochy-sl
# Line 12: 11	Hellboy	2004	Hungarian	hu	2004-11-03 13:03:21	167190	srt	2	Hellboy.2004.DVDRip.XviD-DVP	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/11/hellboy-hu
# Line 13: 12	American Gun	2002	Slovenian	sl	2004-11-03 13:36:45	270197	sub	1	American Gun	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/12/american-gun-sl
# Line 14: 13	The Legend of Drunken Master	1994	English	en	2004-11-04 17:11:34	111512	srt	1	 Drunken.Master.2.Uncut.DVD-Rip.By.Ghost	23.976	0	0	0	movie	http://www.opensubtitles.org/subtitles/13/the-legend-of-drunken-master-en
# Line 15: 4062580	"Bones" The Bodies in the Book	2007	Portuguese (BR)	pb	2011-01-22 07:33:42	934029	srt	1	 Bones.02x15	23.976	2	15	460627	tv	http://www.opensubtitles.org/subtitles/4062580/bones-the-bodies-in-the-book-pb
# Line 16: 14	House of Flying Daggers	2004	English	en	2004-11-04 17:16:21	385004	srt	2	 House.Of.Flying.Daggers.2004.RETAIL.DVDRip.XViD-TLF	23.976	0	0	0	movie	http://www.opensubtitles.org/subtitles/14/house-of-flying-daggers-en
# Line 17: 15	Femme Fatale	2002	Hungarian	hu	2004-11-04 20:08:30	280665	srt	1	Femme.Fatale.DVDRip.XViD-ViTE	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/15/femme-fatale-hu
# Line 18: 16	Lu ding ji	1992	English	en	2004-11-04 20:45:50	104770	srt	1	 Stephen Chow - Royal Tramp 1	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/16/lu-ding-ji-en
# Line 19: 17	Rashomon	1950	English	en	2004-11-04 20:52:44	42876	srt	1	 rashomon_(1950).earthling10480.sharereactor	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/17/rashomon-en
# Line 20: 18	Rashomon	1950	English	en	2004-11-04 20:52:44	42876	smi	1	 rashomon_(1950).garandou.sharereactor	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/18/rashomon-en
# Line 21: 4419719	The Valdemar Legacy	2010	Romanian	ro	2011-11-28 00:16:20	1242744	srt	1	 La.herencia.Valdemar.2010.720p.BluRay.x264-DON	24.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/4419719/the-valdemar-legacy-ro
# Line 22: 4419721	"The Big Bang Theory" The Flaming Spittoon Acquisition	2011	Hungarian	hu	2011-11-28 00:20:11	2105978	srt	1	The.Big.Bang.Theory.S05E10.HDTV.Swesub.XviD-Flashern95	23.976	5	10	898266	tv	http://www.opensubtitles.org/subtitles/4419721/the-big-bang-theory-the-flaming-spittoon-acquisition-hu
# Line 23: 20	Hei kek ji wong	1999	English	en	2004-11-04 20:58:02	188766	srt	1	 King of Comedy	23.980	0	0	0	movie	http://www.opensubtitles.org/subtitles/20/hei-kek-ji-wong-en
# Line 24: 21	Spirited Away	2001	English	en	2004-11-04 21:04:23	245429	sub	2	 Spirited Away - DVDRip	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/21/spirited-away-en
# Line 25: 4420392	Atlas Shrugged: Part I	2011	Dutch	nl	2011-11-29 00:16:57	480239	srt	1	Atlas.Shrugged.Part.1.LIMITED.2011.BRRip.XviD-LORE.NovasetRG	23.976	0	0	0	movie	http://www.opensubtitles.org/subtitles/4420392/atlas-shrugged-part-i-nl
# Line 26: 4420394	The Pianist	2002	Slovak	sk	2011-11-29 00:18:09	253474	srt	1	The Pianist (moviesbyrizzo) HD	29.970	0	0	0	movie	http://www.opensubtitles.org/subtitles/4420394/the-pianist-sk
# Line 27: 23	Back to the Future Part II	1989	English	en	2004-11-04 21:15:46	96874	srt	2	 Back To The Future II - English	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/23/back-to-the-future-part-ii-en
# Line 28: 24	Ghost Ship	2002	English	en	2004-11-04 21:47:29	288477	srt	1	 Ghost Ship.English	25.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/24/ghost-ship-en
# Line 29: 25	Ghost Ship	2002	Hungarian	hu	2004-11-04 21:47:29	288477	srt	1	Ghost.Ship.DVDRip.XviD-ViTE	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/25/ghost-ship-hu
# Line 30: 26	Royal Tramp II	1992	English	en	2004-11-04 21:55:18	104771	srt	1	 Stephen Chow - Royal Tramp 2	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/26/royal-tramp-ii-en
# Line 31: 4421144	"Rome" Death Mask	2007	Polish	pl	2011-11-30 00:20:06	901366	mpl	1	 Rome.S02E07.720p.BluRay.x264-MAjUS	0.000	2	7	384766	tv	http://www.opensubtitles.org/subtitles/4421144/rome-death-mask-pl
# Line 32: 28	I Spy	2002	English	en	2004-11-04 22:11:29	297181	srt	1	 I Spy.English	23.976	0	0	0	movie	http://www.opensubtitles.org/subtitles/28/i-spy-en
# Line 33: 29	Dead Ringers	1988	English	en	2004-11-04 22:15:53	94964	srt	1	Dead.Ringers.(1988).DVDRip.DivX3LM	25.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/29/dead-ringers-en
# Line 34: 30	Solaris	2002	Hungarian	hu	2004-11-04 22:18:51	307479	srt	1	Solaris.(2002).DVDScr.XviD-DcN	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/30/solaris-hu
# Line 35: 4421697	Lions for Lambs	2007	Bulgarian	bg	2011-12-01 00:15:50	891527	srt	1	 nova.s37e16.hdtv.xvid-fqm	29.970	0	0	0	movie	http://www.opensubtitles.org/subtitles/4421697/lions-for-lambs-bg
# Line 36: 4421698	Scooby-Doo and the Legend of the Vampire	2003	Romanian	ro	2011-12-01 00:18:50	357139	srt	1	 Scooby-Doo.And.The.Legend.of.The.Vampire.2003.BluRay.720p.DTS.x264-CHD	29.970	0	0	0	movie	http://www.opensubtitles.org/subtitles/4421698/scooby-doo-and-the-legend-of-the-vampire-ro
# Line 37: 32	Godzilla Against MechaGodzilla	2002	English	en	2004-12-12 17:45:41	314111	srt	2	 Godzilla X MechaGodzilla (Hand Made)	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/32/godzilla-against-mechagodzilla-en
# Line 38: 33	The Lord of the Rings: The Return of the King	2003	Hebrew	he	2004-12-18 14:52:25	167260	srt	3	alli-lotr.rotk.ee.cd1	25.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/33/the-lord-of-the-rings-the-return-of-the-king-he
# Line 39: 34	Bad Santa	2003	Swedish	sv	2004-12-18 21:54:22	307987	srt	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/34/bad-santa-sv
# Line 40: 35	White Chicks	2004	Swedish	sv	2004-12-18 21:59:22	381707	srt	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/35/white-chicks-sv
# Line 41: 36	Shrek	2001	Swedish	sv	2004-12-18 22:04:18	126029	sub	1		23.976	0	0	0	movie	http://www.opensubtitles.org/subtitles/36/shrek-sv
# Line 42: 37	Cruel Intentions 2	2000	Swedish	sv	2004-12-18 22:09:14	196267	srt	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/37/cruel-intentions-2-sv
# Line 43: 38	Finding Nemo	2003	Swedish	sv	2004-12-18 22:18:48	266543	srt	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/38/finding-nemo-sv
# Line 44: 39	Ice Age	2002	Swedish	sv	2004-12-18 22:23:41	268380	sub	1		23.976	0	0	0	movie	http://www.opensubtitles.org/subtitles/39/ice-age-sv
# Line 45: 40	Leon: The Professional	1994	Swedish	sv	2004-12-18 22:29:18	110413	srt	1	 Leon	23.976	0	0	0	movie	http://www.opensubtitles.org/subtitles/40/leon-the-professional-sv
# Line 46: 41	The Boondock Saints	1999	Swedish	sv	2004-12-18 22:33:15	144117	sub	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/41/the-boondock-saints-sv
# Line 47: 42	21 Grams	2003	Swedish	sv	2004-12-18 22:44:14	315733	srt	2		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/42/21-grams-sv
# Line 48: 43	Ju-On: The Grudge 2	2003	Swedish	sv	2004-12-18 22:50:00	367913	srt	1	 Ju-on - The Grudge 2	24.270	0	0	0	movie	http://www.opensubtitles.org/subtitles/43/ju-on-the-grudge-2-sv
# Line 49: 44	Wrong Turn	2003	Swedish	sv	2004-12-18 22:55:04	295700	srt	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/44/wrong-turn-sv
# Line 50: 45	Signs	2002	Swedish	sv	2004-12-18 23:01:13	286106	sub	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/45/signs-sv
# Line 51: 46	Monster	2003	Swedish	sv	2004-12-20 15:36:49	340855	sub	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/46/monster-sv
# Line 52: 47	Stuck on You	2003	Swedish	sv	2004-12-20 15:58:12	338466	srt	2		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/47/stuck-on-you-sv
# Line 53: 4731920	"Criminal Minds" Doubt	2007	Spanish	es	2012-12-03 00:19:42	1093934	srt	1		23.976	3	1	452046	tv	http://www.opensubtitles.org/subtitles/4731920/criminal-minds-doubt-es
# Line 54: 4731921	"Criminal Minds" In Name and Blood	2007	Spanish	es	2012-12-03 00:19:42	1111159	srt	1		23.976	3	2	452046	tv	http://www.opensubtitles.org/subtitles/4731921/criminal-minds-in-name-and-blood-es
# Line 55: 49	I, Robot	2004	Swedish	sv	2004-12-21 19:41:39	343818	srt	2		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/49/i-robot-sv
# Line 56: 50	Not Another Teen Movie	2001	Swedish	sv	2004-12-21 19:45:06	277371	srt	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/50/not-another-teen-movie-sv
# Line 57: 51	Resident Evil	2002	Swedish	sv	2004-12-21 19:47:03	120804	srt	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/51/resident-evil-sv
# Line 58: 52	Shaun of the Dead	2004	Swedish	sv	2004-12-21 19:48:55	365748	srt	1		25.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/52/shaun-of-the-dead-sv
# Line 59: 53	The Football Factory	2004	Swedish	sv	2004-12-21 19:51:27	385705	srt	1		25.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/53/the-football-factory-sv
# Line 60: 54	Coyote Ugly	2000	Swedish	sv	2004-12-26 22:59:39	200550	srt	1		0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/54/coyote-ugly-sv
# --- End of file sample ---

# %%
import pandas as pd
import gzip

metadata_path = "subtitles_all.txt.gz"
correct_separator = '\t' # Confirmed from your previous output

print("--- Running Step 2: Loading Metadata ---")
try:
    # Load the data into the variable named metadata_df
    metadata_df = pd.read_csv(
        metadata_path,
        compression='gzip',
        sep=correct_separator,
        low_memory=False
        # Add error handling like quoting=3 or on_bad_lines='skip' if needed,
        # but start with just the correct separator.
    )
    print("Metadata loaded successfully into 'metadata_df'.")
    print("Shape:", metadata_df.shape)
    print("Columns:", metadata_df.columns.tolist())
    print("First 3 rows:\n", metadata_df.head(3))

except FileNotFoundError:
     print(f"Error: The file '{metadata_path}' was not found. Check the path.")
except Exception as e:
    print(f"Error loading metadata: {e}")
    # If you still get errors here, inspect the error message.
    # It might be a quoting issue (try adding quoting=3 inside read_csv)
    # or specific problematic lines (try on_bad_lines='warn' or on_bad_lines='skip')

print("--- Finished Step 2 ---")

# ---- NOW YOU CAN RUN THE STEP 3 CODE ----
# (The code block you ran previously that started with 'import sqlite3...')
# Make sure 'metadata_df' now exists before proceeding.
if 'metadata_df' in locals():
     print("\n'metadata_df' exists. Proceeding to run Step 3 code...")
     # PASTE THE ENTIRE STEP 3 CODE HERE or run the cell containing it
else:
     print("\nError: 'metadata_df' still not loaded. Fix Step 2 before running Step 3.")
# Out:
# --- Running Step 2: Loading Metadata ---
# Error loading metadata: Error tokenizing data. C error: Expected 16 fields in line 2895, saw 17
#
# --- Finished Step 2 ---
#
# Error: 'metadata_df' still not loaded. Fix Step 2 before running Step 3.

# %%
import sqlite3
import pandas as pd # Make sure pandas is imported
import io
import zipfile
import random # To select random samples

# --- Prerequisites ---
# 1. Ensure 'metadata_df' is loaded correctly from Step 2, for example:
# metadata_path = "subtitles_all.txt.gz"
# metadata_df = pd.read_csv(metadata_path, compression='gzip', sep='\t', low_memory=False)
# print("Metadata loaded successfully. Shape:", metadata_df.shape)

# 2. Define database path
db_path = "opensubs.db"

# 3. Define the linking columns (based on inspection)
id_column_in_metadata = 'IDSubtitle' # From subtitles_all.txt.gz header
id_column_in_db = 'num'            # Primary key from subz table schema

# 4. Check if metadata DataFrame exists and has the ID column
if 'metadata_df' not in locals():
    print("Error: metadata_df does not exist. Please load it first (Step 2).")
elif id_column_in_metadata not in metadata_df.columns:
    print(f"Error: Column '{id_column_in_metadata}' not found in metadata_df.")
else:
    print("Proceeding with Step 3: Connecting Metadata and Subtitle Content...")

    # --- Sampling ---
    sample_size = 15 # How many subtitles to sample and extract
    try:
        # Get a list of valid IDs from the metadata, drop missing values, ensure unique
        valid_ids = metadata_df[id_column_in_metadata].dropna().unique()
        # Select random sample IDs
        if len(valid_ids) < sample_size:
             print(f"Warning: Requested sample size {sample_size} is larger than available unique valid IDs {len(valid_ids)}. Using all valid IDs.")
             sample_ids = valid_ids.tolist()
        else:
             sample_ids = random.sample(list(valid_ids), sample_size)

        # Convert IDs to integers for the SQL query as 'num' is INTEGER
        sample_ids_int = [int(id) for id in sample_ids]
        print(f"\nSelected sample IDs: {sample_ids_int}")

    except Exception as e:
        print(f"Error during sampling: {e}")
        sample_ids_int = [] # Prevent further execution if sampling fails

    # --- Database Connection and Querying ---
    if sample_ids_int: # Only proceed if we have IDs to query
        conn = None # Initialize conn to None for finally block
        try:
            conn = sqlite3.connect(db_path)
            cursor = conn.cursor()

            # Prepare the query to fetch BLOBs for these IDs
            placeholders = ','.join('?' * len(sample_ids_int))
            # Select the ID, name hint, and the blob data
            query = f"SELECT {id_column_in_db}, name, file FROM subz WHERE {id_column_in_db} IN ({placeholders})"

            print(f"\nExecuting query: {query.replace('?', '%s') % tuple(sample_ids_int)}") # Show query for debugging

            # Fetch the data
            cursor.execute(query, sample_ids_int)
            sample_rows = cursor.fetchall()
            print(f"\nFetched {len(sample_rows)} rows from the database for the sampled IDs.")

            # --- Process Each Fetched Row (Extract and Analyze) ---
            for row in sample_rows:
                sub_id, name_field, blob_data = row
                print(f"\n--- Processing DB ID (num): {sub_id}, Filename hint: {name_field} ---")

                if not blob_data:
                    print("  Skipping: No blob data found in database for this ID.")
                    continue

                try:
                    # Use io.BytesIO to treat the blob data like an in-memory file
                    zip_buffer = io.BytesIO(blob_data)

                    # Open the zip archive using a 'with' statement
                    with zipfile.ZipFile(zip_buffer, 'r') as zip_ref:
                        file_list = zip_ref.namelist()
                        print(f"  Files inside ZIP: {file_list}")

                        if not file_list:
                            print("  Skipping: ZIP archive is empty.")
                            continue

                        # Attempt to read the first file in the archive
                        subtitle_filename = file_list[0]
                        print(f"  Attempting to read: {subtitle_filename}")

                        # Open the file within the zip archive
                        with zip_ref.open(subtitle_filename) as subtitle_file:
                            # Read the raw bytes first
                            raw_content = subtitle_file.read()

                            # Attempt to decode using common encodings
                            content = None
                            encodings_to_try = ['utf-8', 'latin-1', 'cp1252'] # Add more if needed
                            for enc in encodings_to_try:
                                try:
                                    content = raw_content.decode(enc)
                                    print(f"  Successfully decoded with '{enc}'.")
                                    break # Stop trying once successful
                                except UnicodeDecodeError:
                                    continue # Try the next encoding
                                except Exception as decode_err:
                                    print(f"  Error during decoding with {enc}: {decode_err}")
                                    break # Stop if other error occurs

                            if content:
                                print(f"  First 200 chars:\n{content[:200].replace(chr(13),' ')}...") # Replace CR sometimes helps display
                                # --- Basic analysis on 'content' ---
                                line_count = len(content.splitlines())
                                word_count = len(content.split()) # Simple split by whitespace
                                print(f"  Analysis: Line count approx: {line_count}, Word count approx: {word_count}")
                            else:
                                print("  Failed to decode subtitle content with tried encodings.")

                except zipfile.BadZipFile:
                    print("  Skipping: Invalid or corrupted ZIP file.")
                except IndexError:
                     print("  Skipping: Could not access file list (IndexError).")
                except Exception as e:
                    print(f"  An error occurred processing blob for ID {sub_id}: {e}")

        except sqlite3.Error as sql_err:
            print(f"Database error: {sql_err}")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")
        finally:
            # Ensure the database connection is closed
            if conn:
                conn.close()
                print("\nDatabase connection closed.")
    else:
         print("\nSkipping database query because no valid sample IDs were generated.")
# Out:
# Error: metadata_df does not exist. Please load it first (Step 2).

# %%
import gzip

metadata_path = "subtitles_all.txt.gz"
target_line = 2895
context = 3 # Show a few lines before and after

print(f"--- Inspecting lines around {target_line} in {metadata_path} ---")
try:
    with gzip.open(metadata_path, 'rt', encoding='utf-8') as f:
        for i, line in enumerate(f):
            line_num = i + 1
            if target_line - context <= line_num <= target_line + context:
                print(f"Line {line_num}: {line.strip()}")
            if line_num > target_line + context:
                break
except Exception as e:
    print(f"Error reading file: {e}")
    # Consider trying other encodings like 'latin-1' if utf-8 fails
print("--- End of file inspection ---")
# Out:
# --- Inspecting lines around 2895 in subtitles_all.txt.gz ---
# Line 2892: 2481	In Harm's Way	1965	English	en	2005-03-01 00:00:00	59309	srt	2	In Harm's Way	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/2481/in-harm-s-way-en
# Line 2893: 2482	Bunny Lake Is Missing	1965	English	en	2005-03-01 00:00:00	58997	srt	1	Bunny Lake Is Missing	0.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/2482/bunny-lake-is-missing-en
# Line 2894: 2483	Dark Habits	1983	English	en	2005-03-01 00:00:00	85496	srt	1	Entre tinieblas (Dark Habits)	24.999	0	0	0	movie	http://www.opensubtitles.org/subtitles/2483/dark-habits-en
# Line 2895: 2484	What Have I Done to Deserve This?	1984	English	en	2005-03-01 00:00:00	88461	srt	1	¿Qué he hecho yo para merecer esto!! Poster 	 SEE RANK ¿Qué he hecho yo para merecer esto!!	25.000	0	0	0	movie	http://www.opensubtitles.org/subtitles/2484/what-have-i-done-to-deserve-this-en
# Line 2896: 6448582	"Downton Abbey" Episode #3.6	2012	Polish	pl	2016-01-04 13:28:13	2385246	sub	1	 Downton.Abbey.S03E06.720p.x264.MIKY	0.000	3	6	1606375	tv	http://www.opensubtitles.org/subtitles/6448582/downton-abbey-episode-3-6-pl
# Line 2897: 4746295	The Secret Life of Words	2005	Romanian	ro	2012-12-20 18:38:10	430576	srt	1	The Secret Life Of Words [2005] 720p BRRip  H264 AC3 - CODY	23.976	0	0	0	movie	http://www.opensubtitles.org/subtitles/4746295/the-secret-life-of-words-ro
# Line 2898: 4746297	"Boardwalk Empire" Under God's Power She Flourishes	2011	Polish	pl	2012-12-20 18:40:11	2046372	sub	1	 Boardwalk.Empire.S02E11.HDTV.XviD-ASAP	0.000	2	11	979432	tv	http://www.opensubtitles.org/subtitles/4746297/boardwalk-empire-under-god-s-power-she-flourishes-pl
# --- End of file inspection ---

# %%
import pandas as pd
import gzip
import csv # Still potentially useful for quoting=csv.QUOTE_NONE

metadata_path = "subtitles_all.txt.gz"
correct_separator = '\t'

print("--- Running Step 2: Loading Metadata (Attempt 3 - Skipping Errors) ---")
try:
    metadata_df = pd.read_csv(
        metadata_path,
        compression='gzip',
        sep=correct_separator,
        quoting=csv.QUOTE_NONE, # Keep this, might help other lines
        on_bad_lines='skip',   # <--- ADD THIS LINE TO SKIP BAD LINES
        low_memory=False
    )
    # If loading succeeds, Pandas might issue warnings about skipped lines, which is expected.
    print("Metadata loaded successfully into 'metadata_df' (potentially with skipped rows).")
    print("Shape:", metadata_df.shape) # Check how many rows were loaded vs expected (~5.7 million)
    print("Columns:", metadata_df.columns.tolist())
    print("First 3 rows:\n", metadata_df.head(3))

except FileNotFoundError:
     print(f"Error: The file '{metadata_path}' was not found. Check the path.")
except Exception as e:
    # Catching other potential critical errors during load
    print(f"Error loading metadata even with skipping bad lines: {e}")

print("--- Finished Step 2 ---")

# Check if metadata_df was loaded before trying Step 3
if 'metadata_df' in locals():
     print(f"\n'metadata_df' exists. Proceeding to run Step 3 code...")
     # You can now run your Step 3 code again.
     # PASTE THE ENTIRE STEP 3 CODE HERE or run the cell containing it
else:
     print("\nError: 'metadata_df' still not loaded. Loading failed even with on_bad_lines='skip'. Check previous errors.")
# Out:
# --- Running Step 2: Loading Metadata (Attempt 3 - Skipping Errors) ---
# Metadata loaded successfully into 'metadata_df' (potentially with skipped rows).
# Shape: (5729550, 16)
# Columns: ['IDSubtitle', 'MovieName', 'MovieYear', 'LanguageName', 'ISO639', 'SubAddDate', 'ImdbID', 'SubFormat', 'SubSumCD', 'MovieReleaseName', 'MovieFPS', 'SeriesSeason', 'SeriesEpisode', 'SeriesIMDBParent', 'MovieKind', 'URL']
# First 3 rows:
#    IDSubtitle                        MovieName  MovieYear LanguageName ISO639  \
# 0          1                          Alien 3     1992.0      English     en
# 1          2                         Identity     2003.0    Slovenian     sl
# 2          3  Ghost in the Shell 2: Innocence     2004.0      English     en
#
#             SubAddDate  ImdbID SubFormat  SubSumCD  \
# 0  2004-10-31 23:54:23  103644       sub       2.0
# 1  2004-10-31 23:54:23  309698       sub       1.0
# 2  2004-10-31 23:54:23  347246       srt       1.0
#
#               MovieReleaseName  MovieFPS  SeriesSeason  SeriesEpisode  \
# 0                      Alien.3     11.00           0.0            0.0
# 1         Identity.DVDRiP.XViD      0.00           0.0            0.0
# 2   Innocence.2004.DVDRip.XviD     23.98           0.0            0.0
#
#    SeriesIMDBParent MovieKind  \
# 0               0.0     movie
# 1               0.0     movie
# 2               0.0     movie
#
#                                                  URL
# 0  http://www.opensubtitles.org/subtitles/1/alien...
# 1  http://www.opensubtitles.org/subtitles/2/ident...
# 2  http://www.opensubtitles.org/subtitles/3/ghost...
# --- Finished Step 2 ---
#
# 'metadata_df' exists. Proceeding to run Step 3 code...

# %%
import sqlite3
import pandas as pd # Make sure pandas is imported if in a new cell/script
import io
import zipfile
import random # To select random samples

# --- Prerequisites (Assumed Met) ---
# 1. 'metadata_df' exists from Step 2.
# 2. Database path is correct.

db_path = "opensubs.db"

# Define the linking columns (based on inspection)
id_column_in_metadata = 'IDSubtitle' # From subtitles_all.txt.gz header
id_column_in_db = 'num'            # Primary key from subz table schema

# Check again just in case (good practice)
if 'metadata_df' not in locals():
    print("Error: metadata_df does not exist. Please load it first (Step 2).")
elif id_column_in_metadata not in metadata_df.columns:
    print(f"Error: Column '{id_column_in_metadata}' not found in metadata_df.")
else:
    print("--- Running Step 3: Connect Metadata and Subtitle Content (Sampling) ---")

    # --- Sampling ---
    sample_size = 15 # How many subtitles to sample and extract
    try:
        # Get a list of valid IDs from the metadata, drop missing values, ensure unique
        valid_ids = metadata_df[id_column_in_metadata].dropna().unique()
        # Select random sample IDs
        if len(valid_ids) == 0:
             print("Error: No valid IDs found in the metadata column '{id_column_in_metadata}'. Cannot sample.")
             sample_ids_int = []
        elif len(valid_ids) < sample_size:
             print(f"Warning: Requested sample size {sample_size} is larger than available unique valid IDs {len(valid_ids)}. Using all valid IDs.")
             sample_ids = valid_ids.tolist()
             # Convert IDs to integers for the SQL query as 'num' is INTEGER
             sample_ids_int = [int(id) for id in sample_ids]
        else:
             sample_ids = random.sample(list(valid_ids), sample_size)
             # Convert IDs to integers for the SQL query as 'num' is INTEGER
             sample_ids_int = [int(id) for id in sample_ids]

        if sample_ids_int:
             print(f"\nSelected sample IDs: {sample_ids_int}")

    except Exception as e:
        print(f"Error during sampling: {e}")
        sample_ids_int = [] # Prevent further execution if sampling fails

    # --- Database Connection and Querying ---
    if sample_ids_int: # Only proceed if we have IDs to query
        conn = None # Initialize conn to None for finally block
        try:
            conn = sqlite3.connect(db_path)
            cursor = conn.cursor()

            # Prepare the query to fetch BLOBs for these IDs
            placeholders = ','.join('?' * len(sample_ids_int))
            # Select the ID, name hint, and the blob data
            query = f"SELECT {id_column_in_db}, name, file FROM subz WHERE {id_column_in_db} IN ({placeholders})"

            # Fetch the data
            cursor.execute(query, sample_ids_int)
            sample_rows = cursor.fetchall()
            print(f"\nFetched {len(sample_rows)} rows from the database for the {len(sample_ids_int)} sampled IDs.")
            if len(sample_rows) < len(sample_ids_int):
                 print("  (Note: Some sampled IDs might not exist in the database)")


            # --- Process Each Fetched Row (Extract and Analyze) ---
            for row in sample_rows:
                sub_id, name_field, blob_data = row
                print(f"\n--- Processing DB ID (num): {sub_id}, Filename hint: {name_field} ---")

                if not blob_data:
                    print("  Skipping: No blob data found in database for this ID.")
                    continue

                try:
                    # Use io.BytesIO to treat the blob data like an in-memory file
                    zip_buffer = io.BytesIO(blob_data)

                    # Open the zip archive using a 'with' statement
                    with zipfile.ZipFile(zip_buffer, 'r') as zip_ref:
                        file_list = zip_ref.namelist()
                        print(f"  Files inside ZIP: {file_list}")

                        if not file_list:
                            print("  Skipping: ZIP archive is empty.")
                            continue

                        # Attempt to read the first file in the archive
                        subtitle_filename = file_list[0]
                        print(f"  Attempting to read: {subtitle_filename}")

                        # Open the file within the zip archive
                        with zip_ref.open(subtitle_filename) as subtitle_file:
                            # Read the raw bytes first
                            raw_content = subtitle_file.read()

                            # Attempt to decode using common encodings
                            content = None
                            encodings_to_try = ['utf-8', 'latin-1', 'cp1252'] # Add more if needed
                            for enc in encodings_to_try:
                                try:
                                    content = raw_content.decode(enc)
                                    print(f"  Successfully decoded with '{enc}'.")
                                    break # Stop trying once successful
                                except UnicodeDecodeError:
                                    continue # Try the next encoding
                                except Exception as decode_err:
                                    print(f"  Error during decoding with {enc}: {decode_err}")
                                    break # Stop if other error occurs

                            if content:
                                # Replace carriage returns for potentially cleaner printing
                                clean_content_sample = content[:200].replace('\r', ' ')
                                print(f"  First 200 chars:\n{clean_content_sample}...")
                                # --- Basic analysis on 'content' ---
                                line_count = len(content.splitlines())
                                word_count = len(content.split()) # Simple split by whitespace
                                print(f"  Analysis: Line count approx: {line_count}, Word count approx: {word_count}")
                            else:
                                print("  Failed to decode subtitle content with tried encodings.")

                except zipfile.BadZipFile:
                    print("  Skipping: Invalid or corrupted ZIP file.")
                except IndexError:
                     print("  Skipping: Could not access file list (IndexError).")
                except Exception as e:
                    print(f"  An error occurred processing blob for ID {sub_id}: {e}")

        except sqlite3.Error as sql_err:
            print(f"Database error: {sql_err}")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")
        finally:
            # Ensure the database connection is closed
            if conn:
                conn.close()
                print("\nDatabase connection closed.")
    else:
         print("\nSkipping database query because no valid sample IDs were generated.")

    print("\n--- Finished Step 3 ---")
# Out:
# --- Running Step 3: Connect Metadata and Subtitle Content (Sampling) ---
#
# Selected sample IDs: [4896472, 3880466, 8802174, 8380138, 7188275, 4496982, 5588367, 3886858, 5401298, 4036802, 7006770, 6301994, 4155385, 3414835, 8299439]
#
# Fetched 15 rows from the database for the 15 sampled IDs.
#
# --- Processing DB ID (num): 3414835, Filename hint: attachment; filename="millers.crossing.(1990).pol.1cd.(3414835).zip" ---
#   Files inside ZIP: ["01.1990.Miller's.Crossing.movie.dvdrip.avi.hokusbloke.txt", 'miller.s.crossing.(3414835).nfo']
#   Attempting to read: 01.1990.Miller's.Crossing.movie.dvdrip.avi.hokusbloke.txt
#   Successfully decoded with 'latin-1'.
#   First 200 chars:
# {1}{100}www.napiprojekt.pl - nowa jakoæ napisów.|Napisy zosta³y specjalnie dopasowane do Twojej wersji filmu.
# {125}{275}-== [ www.OpenSubtitles.org ] ==-
# {710}{778}Mówiê o przyjani.
# {780}{860}Mów...
#   Analysis: Line count approx: 1347, Word count approx: 7978
#
# --- Processing DB ID (num): 3880466, Filename hint: attachment; filename="my.own.worst.enemy.s01.e01.breakdown.(2008).scc.1cd.(3880466).zip" ---
#   Files inside ZIP: ['My Own Worst Enemy - 01x01.HDTV.XviD-LOL.srt', 'my.own.worst.enemy.breakdown.(3880466).nfo']
#   Attempting to read: My Own Worst Enemy - 01x01.HDTV.XviD-LOL.srt
#   Successfully decoded with 'latin-1'.
#   First 200 chars:
# 1
# 00:00:02,009 --> 00:00:03,374
# Moje ime je edward.
#
# 2
# 00:00:03,374 --> 00:00:05,243
# Do sada, si zaboravio sve
# o meni.
#
# 3
# 00:00:05,309 --> 00:00:08,273
# Ali moras da slusas veoma pazljivo
# ...
#   Analysis: Line count approx: 3316, Word count approx: 6965
#
# --- Processing DB ID (num): 3886858, Filename hint: attachment; filename="terminator.the.sarah.connor.chronicles.s02.e15.desert.cantos.(2009).est.1cd.(3886858).zip" ---
#   Files inside ZIP: ['Terminator.The.Sarah.Connor.Chronicles.S02E15.HDTV.XviD-NoTV.srt', 'terminator.the.sarah.connor.(3886858).nfo']
#   Attempting to read: Terminator.The.Sarah.Connor.Chronicles.S02E15.HDTV.XviD-NoTV.srt
#   Successfully decoded with 'latin-1'.
#   First 200 chars:
# 1
# 00:00:00,134 --> 00:00:03,033
# Eelnevalt:
#
# 2
# 00:00:03,034 --> 00:00:05,434
# Kus on metall?
#
# 3
# 00:00:06,833 --> 00:00:09,734
# Kes sa oled?
# - Mu nimi on Winston.
#
# 4
# 00:00:10,667 --> 00:00:1...
#   Analysis: Line count approx: 1910, Word count approx: 4467
#
# --- Processing DB ID (num): 4036802, Filename hint: attachment; filename="southland.s01.e06.westside.(2009).por.1cd.(4036802).zip" ---
#   Files inside ZIP: ['Southland.S01E06.REPACK.HDTV.XviD-XII.srt', 'southland.westside.(4036802).nfo']
#   Attempting to read: Southland.S01E06.REPACK.HDTV.XviD-XII.srt
#   Successfully decoded with 'latin-1'.
#   First 200 chars:
# 1
# 00:00:06,000 --> 00:00:12,074
# Anuncie o seu produto ou marca aqui
# Contacte www.OpenSubtitles.org
#
# 2
# 00:00:43,277 --> 00:00:46,198
# <i>O agente Ben Sherman sabia que
# era contra a política da p...
#   Analysis: Line count approx: 3041, Word count approx: 6840
#
# --- Processing DB ID (num): 4155385, Filename hint: attachment; filename="the.adjustment.bureau.(2011).scc.1cd.(4155385).zip" ---
#   Files inside ZIP: ['The Adjustment Bureau.srt', 'the.adjustment.bureau.(4155385).nfo']
#   Attempting to read: The Adjustment Bureau.srt
#   Successfully decoded with 'latin-1'.
#   First 200 chars:
# 1
# 00:00:06,000 --> 00:00:12,074
# ÐÐ¾Ð´ÑÐ¶Ð¸ÑÐµ Ð½Ð°Ñ Ð¸ Ð¿Ð¾ÑÑÐ°Ð½Ð¸ÑÐµ VIP ÑÐ»Ð°Ð½ Ð´Ð° Ð±Ð¸ÑÑÐµ ÑÐºÐ»Ð¾Ð½Ð¸Ð»Ð¸ ÑÐ²Ðµ Ð¾Ð³Ð»Ð°ÑÐµ ÑÐ° www.OpenSubtitles.org
#
# 2
# 00:00:46,914 --> 00:0...
#   Analysis: Line count approx: 4747, Word count approx: 9968
#
# --- Processing DB ID (num): 4496982, Filename hint: attachment; filename="the.secret.circle.s01.e17.curse.(2012).ita.1cd.(4496982).zip" ---
#   Files inside ZIP: ['The.Secret.Circle.1x17.Curse.HDTV.XviD-2HD.srt', 'the.secret.circle.curse.(4496982).nfo']
#   Attempting to read: The.Secret.Circle.1x17.Curse.HDTV.XviD-2HD.srt
#   Successfully decoded with 'latin-1'.
#   First 200 chars:
# 1
# 00:00:00,131 --> 00:00:01,848
# <i>Negli episodi precedenti...</i>
#
# 2
# 00:00:01,849 --> 00:00:03,941
# - Cos'è?
# - E' un totem del potere.
#
# 3
# 00:00:04,061 --> 00:00:06,356
# Elimina le debolezze ...
#   Analysis: Line count approx: 2540, Word count approx: 5831
#
# --- Processing DB ID (num): 4896472, Filename hint: attachment; filename="seinfeld.s02.e04.the.phone.message.(1991).rum.1cd.(4896472).zip" ---
#   Files inside ZIP: ['Seinfeld.2x04.The_Phone_Message.DVDrip_XviD-FoV.sub', 'seinfeld.the.phone.message.(4896472).nfo']
#   Attempting to read: Seinfeld.2x04.The_Phone_Message.DVDrip_XviD-FoV.sub
#   Successfully decoded with 'latin-1'.
#   First 200 chars:
# {60}{107}Lucrul nasol la televiziune...
# {110}{200}e ca toþi cei vãzuþi la televizor|fac ceva mai bun...
# {205}{240}decât ceea ce faci tu.
# {295}{355}Niciodatã nu vezi la TV|pe cineva stând pe sofa......
#   Analysis: Line count approx: 419, Word count approx: 2429
#
# --- Processing DB ID (num): 5401298, Filename hint: attachment; filename="winter.in.wartime.(2008).scc.1cd.(5401298).zip" ---
#   Files inside ZIP: ['Oorlogswinter.2008.Blu-ray.Rip.a720.X264.dd51.MySilu.srt', 'winter.in.wartime.(5401298).nfo']
#   Attempting to read: Oorlogswinter.2008.Blu-ray.Rip.a720.X264.dd51.MySilu.srt
#   Successfully decoded with 'utf-8'.
#   First 200 chars:
# 1
# 00:00:06,000 --> 00:00:12,074
# Подржите нас и постаните VIP члан да бисте уклонили све огласе са www.OpenSubtitles.org
#
# 2
# 00:03:38,708 --> 00:03:42,708
# www.titlovi.com
#
# 3
# 00:03:45,708 --> 00...
#   Analysis: Line count approx: 1504, Word count approx: 3047
#
# --- Processing DB ID (num): 5588367, Filename hint: attachment; filename="continuum.s03.e01.minute.by.minute.(2014).eng.1cd.(5588367).zip" ---
#   Files inside ZIP: ['C.Users.Ivandrofly.Downloads.Subtitle To Upload.New folder.Continuum.S03E01.HDTV.XviD-EVO.srt', 'continuum.minute.by.minute.(5588367).nfo']
#   Attempting to read: C.Users.Ivandrofly.Downloads.Subtitle To Upload.New folder.Continuum.S03E01.HDTV.XviD-EVO.srt
#   Successfully decoded with 'utf-8'.
#   First 200 chars:
# ﻿1
# 00:00:01,000 --> 00:00:06,070
# http://subscene.com/u/659433
# Improved by: @Ivandrofly
#
# 2
# 00:00:06,072 --> 00:00:07,248
# <i>Previously on Continuum...</i>
#
# 3
# 00:00:07,273 --> 00:00:08,273
# Wh...
#   Analysis: Line count approx: 3025, Word count approx: 6427
#
# --- Processing DB ID (num): 6301994, Filename hint: attachment; filename="the.big.bang.theory.s02.e23.the.monopolar.expedition.(2009).pob.1cd.(6301994).zip" ---
#   Files inside ZIP: ['The.Big.Bang.Theory.S02E23.720p.BluRay.x264-CLUE.srt', 'the.big.bang.theory.the.(6301994).nfo']
#   Attempting to read: The.Big.Bang.Theory.S02E23.720p.BluRay.x264-CLUE.srt
#   Successfully decoded with 'latin-1'.
#   First 200 chars:
# 1
# 00:00:04,953 --> 00:00:07,114
# Ave.
#
# 2
# 00:00:08,315 --> 00:00:09,507
# O quê?
#
# 3
# 00:00:09,508 --> 00:00:14,445
# Não posso comentar sem violar o nosso
# acordo de não criticar o seu trabalho.
# ...
#   Analysis: Line count approx: 1500, Word count approx: 3678
#
# --- Processing DB ID (num): 7006770, Filename hint: attachment; filename="random.tropical.paradise.(2017).eng.1cd.(7006770).zip" ---
#   Files inside ZIP: ['Random.Tropical.Paradise.2017.WEB-DL.x264-FGT.srt', 'random.tropical.paradise.(7006770).nfo']
#   Attempting to read: Random.Tropical.Paradise.2017.WEB-DL.x264-FGT.srt
#   Successfully decoded with 'utf-8'.
#   First 200 chars:
# ﻿1
# 00:00:06,000 --> 00:00:12,074
# Who are the real-world Illuminati ?
# Find out @ saveanilluminati.com
#
# 2
# 00:01:17,910 --> 00:01:19,511
# Oh! Ah!
#
# 3
# 00:01:22,248 --> 00:01:24,516
# Oh, fuck! Oh, ...
#   Analysis: Line count approx: 9970, Word count approx: 23125
#
# --- Processing DB ID (num): 7188275, Filename hint: attachment; filename="doroppu.(2009).ind.1cd.(7188275).zip" ---
#   Files inside ZIP: ['Drop (2009).srt', 'doroppu.(7188275).nfo']
#   Attempting to read: Drop (2009).srt
#   Successfully decoded with 'utf-8'.
#   First 200 chars:
# 00:00:05,545 --> 00:00:12,001
# Subtitle by : Ruby Anumerta
# Join Fb Group : ASIAN MOVIE MANIA
#
# 2
# 00:00:12,545 --> 00:00:16,311
# Anak itu kapan pindah kemari
#
# 3
# 00:00:16,449 --> 00:00:17,473
# Har...
#   Analysis: Line count approx: 4747, Word count approx: 8586
#
# --- Processing DB ID (num): 8299439, Filename hint: attachment; filename="save.me.s02.e01.episode.2.1.(2019).pol.1cd.(8299439).zip" ---
#   Files inside ZIP: ['save.me.uk.s02e01.internal.720p.ahdtv.x264-failed.srt', 'save.me.episode.2.1.(8299439).nfo']
#   Attempting to read: save.me.uk.s02e01.internal.720p.ahdtv.x264-failed.srt
#   Successfully decoded with 'latin-1'.
#   First 200 chars:
# 1
# 00:00:04,300 --> 00:00:07,400
# <i>Nie martw siê o mnie, mamo.</i>
# <i>Nic mi nie jest.</i>
#
# 2
# 00:00:08,400 --> 00:00:10,700
# <i>To co naprawdê cudownego.</i>
#
# 3
# 00:00:12,800 --> 00:00:15,500...
#   Analysis: Line count approx: 2772, Word count approx: 5819
#
# --- Processing DB ID (num): 8380138, Filename hint: attachment; filename="code.404.s01.e06.episode.1.6.(2020).eng.1cd.(8380138).zip" ---
#   Files inside ZIP: ['Code.404.S01E06.WEBRip.x264-ION10-HI.srt', 'code.404.episode.1.6.(8380138).nfo']
#   Attempting to read: Code.404.S01E06.WEBRip.x264-ION10-HI.srt
#   Successfully decoded with 'utf-8'.
#   First 200 chars:
# 1
# 00:00:02,348 --> 00:00:04,508
# [Beeping]
#
# 2
# 00:00:12,468 --> 00:00:14,468
# Major: I know everything.
#
# 3
# 00:00:15,748 --> 00:00:17,748
# Carver: What do you mean
# "everything"?
#
# 4
# 00:00:20,8...
#   Analysis: Line count approx: 2161, Word count approx: 4627
#
# --- Processing DB ID (num): 8802174, Filename hint: attachment; filename="the.shadow.riders.(1982).eng.1cd.(8802174).zip" ---
#   Files inside ZIP: ['The.Shadow.Riders.1982.1080p.AMZN.WEB-DL.DDP2.0.H.264-LycanHD.eng.srt', 'the.shadow.riders.(8802174).nfo']
#   Attempting to read: The.Shadow.Riders.1982.1080p.AMZN.WEB-DL.DDP2.0.H.264-LycanHD.eng.srt
#   Successfully decoded with 'utf-8'.
#   First 200 chars:
# ﻿1
# 00:00:06,000 --> 00:00:12,074
# Who are the real-world Illuminati ?
# Find out @ saveanilluminati.com
#
# 2
# 00:01:28,289 --> 00:01:30,591
# <i>April 1865.</i>
#
# 3
# 00:01:30,624 --> 00:01:33,827
# <i>...
#   Analysis: Line count approx: 4607, Word count approx: 10257
#
# Database connection closed.
#
# --- Finished Step 3 ---

# %%
# Example using pysrt (inside your Step 3 loop after getting 'content')
import pysrt
import io

try:
    subs = pysrt.from_string(content)
    dialogue_only = subs.text # Get dialogue concatenated
    print(f"  Parsed dialogue (first 200 chars): {dialogue_only[:200]}...")
    # You can now iterate through subs: for sub in subs: print(sub.start, sub.end, sub.text)
except Exception as parse_err:
    print(f"  Could not parse SRT structure: {parse_err}")
# Out:
#   Parsed dialogue (first 200 chars): Who are the real-world Illuminati ?
# Find out @ saveanilluminati.com
# <i>April 1865.</i>
# <i>Dear Ma and Pa, I hope
# this letter finds you well.</i>
# <i>I have some good news.</i>
# <i>Word is the war
# may be...

# %%
# Example filtering metadata_df BEFORE sampling in Step 3
metadata_df_filtered = metadata_df[
    (metadata_df['LanguageName'] == 'English') &
    (metadata_df['MovieKind'] == 'movie') &
    (metadata_df['MovieYear'] >= 2010)
].copy()
# Then sample IDs from metadata_df_filtered instead of metadata_df

# %%
metadata_df_filtered
# Out:
#         IDSubtitle       MovieName  MovieYear LanguageName ISO639  \
# 248        4465952   The Rum Diary     2011.0      English     en
# 364        4788064     Sen Kimsin?     2012.0      English     en
# 574        4490619       Abduction     2011.0      English     en
# 756        7699952  Hana wa sakuka     2018.0      English     en
# 891        4550013      Tom Sawyer     2011.0      English     en
# ...            ...             ...        ...          ...    ...
# 5729436    9179986  Jug Jugg Jeeyo     2022.0      English     en
# 5729489    9180049  Detroit Dreams     2022.0      English     en
# 5729490    9180050  Detroit Dreams     2022.0      English     en
# 5729493    9180053        Hope Gap     2019.0      English     en
# 5729547    9180116      Air Murder     2022.0      English     en
#
#                   SubAddDate    ImdbID SubFormat  SubSumCD  \
# 248      2012-02-09 00:16:20    376136       srt       1.0
# 364      2013-01-28 00:17:10   2142883       srt       1.0
# 574      2012-03-15 00:18:19   1600195       srt       1.0
# 756      2019-03-27 14:44:41   7408772       srt       1.0
# 891      2012-05-15 00:19:36   1722484       srt       1.0
# ...                      ...       ...       ...       ...
# 5729436  2022-07-24 06:23:45  13449624       srt       1.0
# 5729489  2022-07-24 09:05:40  15100080       srt       1.0
# 5729490  2022-07-24 09:06:27  15100080       srt       1.0
# 5729493  2022-07-24 09:32:19   7587876       srt       1.0
# 5729547  2022-07-24 10:17:41  19849514       srt       1.0
#
#                                           MovieReleaseName  MovieFPS  \
# 248       The.Rum.Diary.2011.1080p.MKV.X264.AC3.DTS.Eng.NL    23.976
# 364                               Sen kimsin (2012).eng.DP    25.000
# 574               Abduction.2011.BluRay.1080p.DTS.x264-CHD    23.976
# 756               Hana wa Saku ka  (Does The Flower Bloom)    29.970
# 891                                          5rFF-toms480p    24.000
# ...                                                    ...       ...
# 5729436   JugJugg.Jeeyo.2022.1080p.AMZN.WEB-DL.Hindi.DD...     0.000
# 5729489                         WEBRip.800MB.x264-GalaxyRG    23.976
# 5729490                         WEBRip.800MB.x264-GalaxyRG    23.976
# 5729493        Hope.Gap.2019.720p.BluRay.x264.AAC-[YTS.MX]    24.000
# 5729547       TOXIC.2022.1080p.WEB-DL.AAC2.0.H.264-Taengoo     0.000
#
#          SeriesSeason  SeriesEpisode  SeriesIMDBParent MovieKind  \
# 248               0.0            0.0               0.0     movie
# 364               0.0            0.0               0.0     movie
# 574               0.0            0.0               0.0     movie
# 756               0.0            0.0               0.0     movie
# 891               0.0            0.0               0.0     movie
# ...               ...            ...               ...       ...
# 5729436           0.0            0.0               0.0     movie
# 5729489           0.0            0.0               0.0     movie
# 5729490           0.0            0.0               0.0     movie
# 5729493           0.0            0.0               0.0     movie
# 5729547           0.0            0.0               0.0     movie
#
#                                                        URL
# 248      http://www.opensubtitles.org/subtitles/4465952...
# 364      http://www.opensubtitles.org/subtitles/4788064...
# 574      http://www.opensubtitles.org/subtitles/4490619...
# 756      http://www.opensubtitles.org/subtitles/7699952...
# 891      http://www.opensubtitles.org/subtitles/4550013...
# ...                                                    ...
# 5729436  http://www.opensubtitles.org/subtitles/9179986...
# 5729489  http://www.opensubtitles.org/subtitles/9180049...
# 5729490  http://www.opensubtitles.org/subtitles/9180050...
# 5729493  http://www.opensubtitles.org/subtitles/9180053...
# 5729547  http://www.opensubtitles.org/subtitles/9180116...
#
# [122020 rows x 16 columns]

# %%
import sqlite3
import pandas as pd
import io
import zipfile
import json
import os
import pysrt # Make sure pysrt is installed: pip install pysrt
from tqdm import tqdm # For progress bar: pip install tqdm
import time
import random
import csv # For quoting=csv.QUOTE_NONE

# --- Configuration ---
DB_PATH = "opensubs.db"
METADATA_PATH = "subtitles_all.txt.gz"
OUTPUT_JSONL_FILE = "extracted_subtitles_200_movies.jsonl"
ERROR_LOG_FILE = "extraction_errors_200_movies.log"
ENCODINGS_TO_TRY = ['utf-8', 'latin-1', 'cp1252']

NUM_MOVIES_TO_SAMPLE = 200
# Assuming 'ImdbID' reliably identifies a unique movie or TV show parent
MOVIE_ID_COLUMN = 'ImdbID'
SUBTITLE_ID_COLUMN = 'IDSubtitle' # Corresponds to 'num' in DB

# --- Functions (Keep the same as before) ---
def process_db_row(row_data, output_f, error_f):
    """
    Processes a single row from the database, extracts subtitle text,
    and writes it to the output file or logs errors.
    (Identical to the function in the 'extract all' script)
    """
    sub_id, blob_data = row_data
    result = {"id": sub_id, "dialogue": None, "raw_srt": None, "error": None}
    srt_filename = None
    content = None
    decoded = False

    if not blob_data:
        result["error"] = "No blob data"
        log_error(error_f, sub_id, "No blob data")
        output_f.write(json.dumps(result) + '\n')
        return

    try:
        zip_buffer = io.BytesIO(blob_data)
        with zipfile.ZipFile(zip_buffer, 'r') as zip_ref:
            file_list = zip_ref.namelist()
            srt_files = [f for f in file_list if f.lower().endswith('.srt')]
            if srt_files:
                srt_filename = srt_files[0]
            elif file_list:
                 srt_filename = file_list[0]
            else:
                 result["error"] = "ZIP archive is empty"
                 log_error(error_f, sub_id, "ZIP archive is empty")
                 output_f.write(json.dumps(result) + '\n')
                 return

            with zip_ref.open(srt_filename) as subtitle_file:
                raw_content = subtitle_file.read()

            for enc in ENCODINGS_TO_TRY:
                try:
                    content = raw_content.decode(enc)
                    decoded = True
                    break
                except UnicodeDecodeError:
                    continue
                except Exception as decode_err:
                     log_error(error_f, sub_id, f"Unexpected decode error with {enc} on file {srt_filename}: {decode_err}")

            if not decoded:
                result["error"] = f"Failed to decode file {srt_filename} with tried encodings."
                log_error(error_f, sub_id, result["error"])
                output_f.write(json.dumps(result) + '\n')
                return

            result["raw_srt"] = content

            try:
                subs = pysrt.from_string(content)
                result["dialogue"] = subs.text
            except Exception as parse_err:
                result["error"] = f"SRT parsing error: {parse_err}"
                log_error(error_f, sub_id, f"SRT parsing error on file {srt_filename}: {parse_err}")

    except zipfile.BadZipFile:
        result["error"] = "Invalid ZIP file"
        log_error(error_f, sub_id, "Invalid ZIP file")
    except IndexError:
         result["error"] = "Error accessing file list in ZIP"
         log_error(error_f, sub_id, "Error accessing file list in ZIP")
    except Exception as e:
        result["error"] = f"Unexpected processing error: {e}"
        log_error(error_f, sub_id, f"Unexpected processing error: {e}")

    output_f.write(json.dumps(result) + '\n')

def log_error(error_f, sub_id, message):
    """Appends an error message to the log file."""
    timestamp = time.strftime("%Y-%m-%d %H:%M:%S")
    error_f.write(f"{timestamp} | ID: {sub_id} | Error: {message}\n")

# --- Main Execution ---
if __name__ == "__main__":
    print(f"Starting extraction for {NUM_MOVIES_TO_SAMPLE} movies...")
    start_time = time.time()

    metadata_df = None
    subtitle_ids_to_fetch = []

    # --- Step 1: Load Metadata ---
    print(f"\nLoading metadata from '{METADATA_PATH}'...")
    try:
        metadata_df = pd.read_csv(
            METADATA_PATH,
            compression='gzip',
            sep='\t', # Use Tab separator
            quoting=csv.QUOTE_NONE, # Ignore quoting issues
            on_bad_lines='skip', # Skip problematic lines
            low_memory=False
        )
        print(f"Metadata loaded successfully. Shape: {metadata_df.shape}")
        # Check if essential columns exist
        if MOVIE_ID_COLUMN not in metadata_df.columns or SUBTITLE_ID_COLUMN not in metadata_df.columns:
             raise ValueError(f"Required columns ('{MOVIE_ID_COLUMN}', '{SUBTITLE_ID_COLUMN}') not found in metadata.")

    except FileNotFoundError:
         print(f"Error: Metadata file '{METADATA_PATH}' not found.")
         exit()
    except Exception as e:
        print(f"Error loading metadata: {e}")
        exit()

    # --- Step 2: Select 200 Unique Movies ---
    print(f"\nSelecting {NUM_MOVIES_TO_SAMPLE} unique movies based on '{MOVIE_ID_COLUMN}'...")
    try:
        unique_movie_ids = metadata_df[MOVIE_ID_COLUMN].dropna().unique()
        if len(unique_movie_ids) < NUM_MOVIES_TO_SAMPLE:
            print(f"Warning: Found only {len(unique_movie_ids)} unique movie IDs, less than requested {NUM_MOVIES_TO_SAMPLE}. Using all available.")
            sampled_movie_ids = list(unique_movie_ids)
        else:
            sampled_movie_ids = random.sample(list(unique_movie_ids), NUM_MOVIES_TO_SAMPLE)
        print(f"Selected {len(sampled_movie_ids)} movie IDs.")

    except Exception as e:
        print(f"Error during movie sampling: {e}")
        exit()

    # --- Step 3: Find All Subtitle IDs for Selected Movies ---
    print(f"\nFinding subtitle IDs ({SUBTITLE_ID_COLUMN}) for the selected movies...")
    try:
        # Filter metadata for the selected movies
        filtered_metadata = metadata_df[metadata_df[MOVIE_ID_COLUMN].isin(sampled_movie_ids)]
        # Get the corresponding subtitle IDs and ensure they are integers
        subtitle_ids_to_fetch = filtered_metadata[SUBTITLE_ID_COLUMN].dropna().astype(int).unique().tolist()
        print(f"Found {len(subtitle_ids_to_fetch):,} subtitle files associated with the {len(sampled_movie_ids)} selected movies.")

    except Exception as e:
        print(f"Error finding subtitle IDs: {e}")
        exit()

    # --- Step 4: Fetch and Extract Subtitles from DB ---
    if not subtitle_ids_to_fetch:
        print("\nNo subtitle IDs found for the selected movies. Exiting.")
        exit()

    print(f"\nConnecting to database '{DB_PATH}' to extract {len(subtitle_ids_to_fetch)} subtitles...")
    print(f"Output will be written to '{OUTPUT_JSONL_FILE}'")
    print(f"Errors will be logged in '{ERROR_LOG_FILE}'")
    print("-" * 30)

    conn = None
    output_file = None
    error_file = None

    try:
        conn = sqlite3.connect(DB_PATH)
        cursor = conn.cursor()

        # Open files for appending
        output_file = open(OUTPUT_JSONL_FILE, 'a', encoding='utf-8')
        error_file = open(ERROR_LOG_FILE, 'a', encoding='utf-8')

        # Fetch subtitles in batches to avoid huge SQL query strings (optional but good practice)
        batch_size = 500 # How many IDs to query at once
        num_batches = (len(subtitle_ids_to_fetch) + batch_size - 1) // batch_size
        print(f"Processing in {num_batches} batches of up to {batch_size} IDs...")

        processed_count = 0
        with tqdm(total=len(subtitle_ids_to_fetch), unit="subs") as pbar:
            for i in range(0, len(subtitle_ids_to_fetch), batch_size):
                batch_ids = subtitle_ids_to_fetch[i:i+batch_size]
                placeholders = ','.join('?' * len(batch_ids))
                query = f"SELECT num, file FROM subz WHERE num IN ({placeholders})"

                try:
                    cursor.execute(query, batch_ids)
                    rows = cursor.fetchall()
                    for row in rows:
                         process_db_row(row, output_file, error_file)
                         processed_count += 1
                         pbar.update(1) # Update progress bar for each row processed
                except sqlite3.Error as batch_sql_err:
                     log_error(error_file, f"Batch {i//batch_size + 1}", f"Database error during batch query: {batch_sql_err}")
                     pbar.update(len(batch_ids) - cursor.rowcount) # Try to advance progress bar past failed batch

            pbar.close() # Ensure tqdm finishes cleanly if loop finishes early

        print(f"\nProcessed {processed_count} subtitles from the database.")
        if processed_count < len(subtitle_ids_to_fetch):
             print(f"Warning: Expected {len(subtitle_ids_to_fetch)} subtitles based on metadata, but only processed {processed_count} from DB. Some IDs might be missing in the DB.")


    except sqlite3.Error as sql_err:
        print(f"\nDatabase error: {sql_err}")
        if error_file: log_error(error_file, "N/A", f"Database error: {sql_err}")
    except IOError as io_err:
        print(f"\nFile I/O error: {io_err}")
    except Exception as e:
        print(f"\nAn unexpected error occurred: {e}")
        if error_file: log_error(error_file, "N/A", f"Unexpected error: {e}")
    finally:
        # Ensure resources are closed
        # (Cursor closing is handled implicitly when connection closes if not iterated fully)
        if conn:
            conn.close()
            print("Database connection closed.")
        if output_file:
            output_file.close()
            print(f"Output file '{OUTPUT_JSONL_FILE}' closed.")
        if error_file:
            error_file.close()
            print(f"Error log '{ERROR_LOG_FILE}' closed.")

        end_time = time.time()
        duration = end_time - start_time
        print(f"Extraction finished in {duration:.2f} seconds ({duration/60:.2f} minutes).")
# Out:
# Starting extraction for 200 movies...
#
# Loading metadata from 'subtitles_all.txt.gz'...
# Metadata loaded successfully. Shape: (5729550, 16)
#
# Selecting 200 unique movies based on 'ImdbID'...
# Selected 200 movie IDs.
#
# Finding subtitle IDs (IDSubtitle) for the selected movies...
# Found 2,403 subtitle files associated with the 200 selected movies.
#
# Connecting to database 'opensubs.db' to extract 2403 subtitles...
# Output will be written to 'extracted_subtitles_200_movies.jsonl'
# Errors will be logged in 'extraction_errors_200_movies.log'
# ------------------------------
# Processing in 5 batches of up to 500 IDs...
# 100%|█████████▉| 2396/2403 [00:58<00:00, 41.15subs/s]
# Processed 2396 subtitles from the database.
# Warning: Expected 2403 subtitles based on metadata, but only processed 2396 from DB. Some IDs might be missing in the DB.
# Database connection closed.
# Output file 'extracted_subtitles_200_movies.jsonl' closed.
# Error log 'extraction_errors_200_movies.log' closed.
# Extraction finished in 83.45 seconds (1.39 minutes).

# %%
import json
import csv
import os

# --- Configuration ---
input_jsonl_file = 'extracted_subtitles_200_movies.jsonl'
output_csv_file = 'extracted_subtitles_200_movies.csv'
# Define the columns you want in your CSV file (matching keys in the JSON)
fieldnames = ['id', 'dialogue']
# --- Configuration End ---

# Basic check if input file exists
if not os.path.exists(input_jsonl_file):
    print(f"Error: Input file not found at '{input_jsonl_file}'")
else:
    print(f"Starting conversion from '{input_jsonl_file}' to '{output_csv_file}'...")
    lines_processed = 0
    rows_written = 0
    errors_encountered = 0

    try:
        # Open the input JSONL file for reading with UTF-8 encoding
        # Open the output CSV file for writing with UTF-8 encoding
        # newline='' is important to prevent extra blank rows in the CSV
        with open(input_jsonl_file, 'r', encoding='utf-8') as infile, \
             open(output_csv_file, 'w', newline='', encoding='utf-8') as outfile:

            # Create a CSV writer object.
            # csv.QUOTE_MINIMAL tells it to only quote fields containing special characters
            # (like the delimiter (,), quote character ("), or line breaks).
            # Use csv.QUOTE_ALL to quote every field if preferred.
            writer = csv.writer(outfile, quoting=csv.QUOTE_MINIMAL)

            # Write the header row to the CSV file
            writer.writerow(fieldnames)

            # Iterate through each line in the JSONL file
            for line in infile:
                lines_processed += 1
                # Skip potentially empty lines
                if not line.strip():
                    continue

                try:
                    # Parse the JSON string on the current line into a Python dictionary
                    data = json.loads(line)

                    # Extract the data for the specified fields in the correct order
                    # Using .get(field) is safer than data[field] as it returns None
                    # if a key is missing, preventing a KeyError.
                    row_data = [data.get(field) for field in fieldnames]

                    # Write the extracted data as a row in the CSV file
                    writer.writerow(row_data)
                    rows_written += 1

                except json.JSONDecodeError:
                    errors_encountered += 1
                    print(f"Warning: Skipping line {lines_processed} due to invalid JSON: {line.strip()}")
                except Exception as e:
                    errors_encountered += 1
                    print(f"Warning: Skipping line {lines_processed} due to error: {e}")

        print("\nConversion Complete.")
        print(f"Total lines read: {lines_processed}")
        print(f"Rows written to CSV (excluding header): {rows_written}")
        if errors_encountered > 0:
            print(f"Lines skipped due to errors: {errors_encountered}")
        print(f"Output saved to: '{output_csv_file}'")

    except FileNotFoundError:
        # This check is technically redundant due to the os.path.exists above,
        # but good practice in case the file disappears between check and open.
        print(f"Error: Input file disappeared before opening: '{input_jsonl_file}'")
    except IOError as e:
        print(f"Error reading or writing file: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
# Out:
# Starting conversion from 'extracted_subtitles_200_movies.jsonl' to 'extracted_subtitles_200_movies.csv'...
# Warning: Skipping line 546 due to error: need to escape, but no escapechar set
#
# Conversion Complete.
# Total lines read: 2396
# Rows written to CSV (excluding header): 2395
# Lines skipped due to errors: 1
# Output saved to: 'extracted_subtitles_200_movies.csv'
